# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
#
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
import selenium
from selenium import webdriver

# %%
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/'

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
#extracting tag for search bar

search_bar=driver.find_element_by_id('searchInput')
search_bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e63d95d801a8bcf9d8f68fede4576029", element="3a23e485-3161-42e0-8b1e-22a4002e54da")>

# %%
#sending keys
search_bar.send_keys('most-viewed YouTube videos')

# %%
#for search button

search_btn=driver.find_element_by_id('searchButton')
search_btn.click()

# %%
#extracting for name
name_tag=driver.find_elements_by_xpath("//a[@class='mw-redirect']")
name_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e63d95d801a8bcf9d8f68fede4576029", element="cc364a57-4801-4da6-a7e6-2999e9a7e512")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e63d95d801a8bcf9d8f68fede4576029", element="aef2be94-bf7e-4fc8-a791-344e6ececb54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e63d95d801a8bcf9d8f68fede4576029", element="6e6d84e9-8902-40b7-a348-2e677c95e271")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e63d95d801a8bcf9d8f68fede4576029", element="50fa5bed-24de-44d8-a18f-efaf75c299f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e63d95d801a8bcf9d8f68fede4576029", element="9c99a326-d57f-4da9-a0b2-20e461b70f29")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e63d95d801a8bcf9d8f68fede4576029", element="fb9e42c4-797f-4f78-94d4-678c4d06272a")>,
# ...

# %%
Video_Name=[]
for i in name_tag:
    Video_Name.append(i.text)
Video_Name
# Out:
# ['music videos',
#  'Baby Shark Dance',
#  'Baby Shark Dance',
#  'Baby Shark Dance',
#  'Cocomelon – Nursery Rhymes',
#  'Cocomelon – Nursery Rhymes',
#  'Cocomelon – Nursery Rhymes',
#  'The Gummy Bear Song',
#  'Fueled By Ramen',
#  'The Gummy Bear Song',
#  'Osito Gominola – Full Spanish Version – The Gummy Bear Song',
#  'Baby Shark Dance',
#  'Closer',
#  'Cocomelon – Nursery Rhymes',
#  'Cocomelon – Nursery Rhymes',
#  'Baby Shark Dance',
#  'List of most-viewed online trailers in the first 24 hours',
#  'regional restrictions',
#  'regional restrictions',
#  'Wired',
#  '',
#  '']

# %%
driver.close()

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://www.bcci.tv/'

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
driver.close()

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
#
#
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
url='https://www.guru99.com/'

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
tag=driver.find_element_by_xpath("//i[@class='fa fa-star-o']")
tag.click()

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP at current price (19-20)
#
# D) GSDP at current price (18-19)
#
# E) Share(18-19)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
url='http://statisticstimes.com/'

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
#extracting tag for economy

eco=driver.find_element_by_xpath("//button[@class='dropbtn']")
eco
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="0fd582d217c94641014df10f6c42ce7d", element="1b3ee74f-bceb-4b23-bc42-815ec2df2ce1")>

# %%
eco.click()

# %%
Ind=driver.find_element_by_xpath("//div[@class='dropdown-content']")
Ind
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="0fd582d217c94641014df10f6c42ce7d", element="c419e503-5362-449d-a1e7-0c16311c297a")>

# %%
Ind.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-18-8d0ae2d25ac4> in <module>
# ----> 1 Ind.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
# ...

# %%
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n<script>\r\n<!--\r\nif (screen.width <= 699) {\r\ndocument.location = "https://m.statisticstimes.com/index.php";\r\n}\r\n//-->\r\n</script>\r\n<title>StatisticsTimes.com | Collection of Statistics and charts</title>\r\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\r\n<meta name="description" content="Collection of Latest Statistics and charts on economy, population,\r\n      geography, sports etc.">\r\n<link rel="alternate" media="only screen and (max-width: 699px)" href="https://m.statisticstimes.com/index.php">\r\n<link rel="canonical" href="https://statisticstimes.com/index.php">\r\n<link rel="apple-touch-icon" sizes="180x180" href="favicon_io/apple-touch-icon.png">\r\n<link rel="icon" type="image/png" sizes="32x32" href="favicon_io/favicon-32x32.png">\r\n<link rel="icon" type="image/png" sizes="16x16" href="favicon_io/favicon-16x16.png">\r\n<link rel="manifest" href="favicon_io/site.webmanifest">\r\n<link re
# ...

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <script>
# <!--
# if (screen.width <= 699) {
# document.location = "https://m.statisticstimes.com/index.php";
# }
# //-->
# </script>
# <title>StatisticsTimes.com | Collection of Statistics and charts</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Collection of Latest Statistics and charts on economy, population,
#       geography, sports etc." name="description"/>
# <link href="https://m.statisticstimes.com/index.php" media="only screen and (max-width: 699px)" rel="alternate"/>
# <link href="https://statisticstimes.com/index.php" rel="canonical"/>
# <link href="favicon_io/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="favicon_io/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="favicon_io/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="favicon_io/site.webmanifest" rel="manifest"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script>
#    <!--
# if (screen.width <= 699) {
# document.location = "https://m.statisticstimes.com/index.php";
# }
# //-->
#   </script>
#   <title>
#    StatisticsTimes.com | Collection of Statistics and charts
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Collection of Latest Statistics and charts on economy, population,
#       geography, sports etc." name="description"/>
#   <link href="https://m.statisticstimes.com/index.php" media="only screen and (max-width: 699px)" rel="alternate"/>
#   <link href="https://statisticstimes.com/index.php" rel="canonical"/>
#   <link href="favicon_io/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="favicon_io/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="favicon_io/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# ...

# %%
Eco=soup.find('button',class_="dropbtn")
Eco
# Out:
# <button class="dropbtn">Home
#       <i class="fa fa-caret-down"></i>
# </button>

# %%
Eco.click()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b88eb0027f81> in <module>
# ----> 1 Eco.click()
#
# TypeError: 'NoneType' object is not callable

# %%
5. Scrape the details of trending repositories on Github.com.
Url = https://github.com/
    
You have to find the following details:
    
    
A) Repository title
B) Repository description
C) Contributors coun
D) Language used

# %%
url='https://github.com/'

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
url='https://github.com/'

# %%
driver.get('https://github.com/')

# %%
search=driver.find_element_by_xpath("//input[@class='form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus']")

# %%
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="da7a1eec58f59de4a4af2b78eef720a4", element="514454e8-dfc3-4345-a7ce-1e8893245458")>

# %%
search.send_keys('trending repositories')

# %%
driver.get('https://github.com/search?q=trending+repositories')

# %%
name_tag=driver.find_elements_by_xpath("//a[@class='v-align-middle']")
name_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="da7a1eec58f59de4a4af2b78eef720a4", element="8dbe2fb0-5642-41e7-9f0a-e56bf54e7600")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="da7a1eec58f59de4a4af2b78eef720a4", element="9330f508-ad8d-409d-a936-dabdc886429e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="da7a1eec58f59de4a4af2b78eef720a4", element="531848e3-d816-4f48-8d81-692fe2b36e03")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="da7a1eec58f59de4a4af2b78eef720a4", element="7d62c6b8-5f10-4e2e-ab4e-ff7255cae91a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="da7a1eec58f59de4a4af2b78eef720a4", element="38d47fcf-159a-4156-a998-5cd44f9bb5c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="da7a1eec58f59de4a4af2b78eef720a4", element="04304098-13c2-4eb7-8416-564e81a8ca4d")>,
# ...

# %%
Name=[]
for i in name_tag:
    Name.append(i.text)
Name
# Out:
# ['mbadry1/Trending-Deep-Learning',
#  'vitalets/github-trending-repos',
#  'Semigradsky/trending-repositories',
#  'laowch/GithubTrends',
#  'ophobe/trending',
#  'ecrmnn/trending-github',
#  'zhuowenli/githuber',
#  'QasimWani/LeetHub',
#  'andygrunwald/TrendingGithub',
#  'andygrunwald/go-trending']

# %% [markdown]
# 6. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through cod

# %%
url='https://www.billboard.com/'

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
tag=driver.find_element_by_xpath("//a[@class='pill-button text--left shadow--soft']")
tag
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="990712f3-f08c-4f51-8fe9-f6a23309ec66")>

# %%
tag.click()

# %%
name_tag=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
name_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="b1314805-783b-478b-91be-10b960ed8fdf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="c702616f-b778-4e22-bb63-77b48d017b73")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="082f802f-561b-4e1a-8c6b-1cb9f51a8c4b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="328062c1-7fd4-4caa-a9c7-d1d279e8dc19")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="ee33e962-855b-45e9-9cd2-c05184b13847")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="d1023d13-f006-4539-b9c2-042b1521d010")>,
# ...

# %%
Song_Name=[]
for i in name_tag:
    Song_Name.append(i.text)
Song_Name
# Out:
# ['Butter',
#  'Good 4 U',
#  'Levitating',
#  'Peaches',
#  'Leave The Door Open',
#  'Save Your Tears',
#  'Kiss Me More',
#  'Astronaut In The Ocean',
#  'Deja Vu',
#  'Yonaguni',
#  'Montero (Call Me By Your Name)',
#  'Without You',
#  'Forever After All',
#  'Rapstar',
#  'Blinding Lights',
#  'Hats Off',
#  'Drivers License',
#  'Beautiful Mistakes',
#  'Traitor',
#  'Late At Night',
#  'Voice Of The Heroes',
#  'Best Friend',
#  'Heartbreak Anniversary',
#  'Heat Waves',
#  'Calling My Phone',
#  'Favorite Crime',
#  'Lost Cause',
#  'Happier',
#  'Up',
#  'Mood',
#  '2040',
#  'Every Chance I Get',
#  'Telepatia',
#  'How It Feels',
#  'Brutal',
#  'Wockesha',
#  'Wants And Needs',
#  'Famous Friends',
#  'pov',
#  'Gone',
#  'Beat Box',
#  "My Ex's Best Friend",
#  'Still Runnin',
#  'Track Star',
#  'What You Know Bout Love',
#  'Who I Want',
#  'my.life',
#  'Back In Blood',
#  'Time Today',
#  'Lil Bit',
#  'Blame It On You',
#  'Nobody',
#  'Todo de Ti',
# ...

# %%
art_tag=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
art_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="84cb6dda-a27e-4ab3-8e61-060325247d73")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="8427d495-9a9b-4f85-8bed-d6af4c8ff45c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="7a8f3505-c0d9-4c65-b98e-2a8fee6f93d2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="1cf228f2-637b-4458-882e-b8723fbb2208")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="9a4a4826-4182-41c4-9e5d-3164b5d0d4a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="7a30562c-69df-44ed-9549-756fddfeb572")>,
# ...

# %%
Artist=[]
for i in art_tag:
    Artist.append(i.text)
Artist
# Out:
# ['BTS',
#  'Olivia Rodrigo',
#  'Dua Lipa Featuring DaBaby',
#  'Justin Bieber Featuring Daniel Caesar & Giveon',
#  'Silk Sonic (Bruno Mars & Anderson .Paak)',
#  'The Weeknd & Ariana Grande',
#  'Doja Cat Featuring SZA',
#  'Masked Wolf',
#  'Olivia Rodrigo',
#  'Bad Bunny',
#  'Lil Nas X',
#  'The Kid LAROI',
#  'Luke Combs',
#  'Polo G',
#  'The Weeknd',
#  'Lil Baby, Lil Durk & Travis Scott',
#  'Olivia Rodrigo',
#  'Maroon 5 Featuring Megan Thee Stallion',
#  'Olivia Rodrigo',
#  'Roddy Ricch',
#  'Lil Baby & Lil Durk',
#  'Saweetie Featuring Doja Cat',
#  'Giveon',
#  'Glass Animals',
#  'Lil Tjay Featuring 6LACK',
#  'Olivia Rodrigo',
#  'Billie Eilish',
#  'Olivia Rodrigo',
#  'Cardi B',
#  '24kGoldn Featuring iann dior',
#  'Lil Baby & Lil Durk',
#  'DJ Khaled Featuring Lil Baby & Lil Durk',
#  'Kali Uchis',
#  'Lil Baby & Lil Durk',
#  'Olivia Rodrigo',
#  'Moneybagg Yo',
#  'Drake Featuring Lil Baby',
#  'Chris Young + Kane Brown',
#  'Ariana Grande',
# ...

# %%
lw_tag=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
lw_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="f1867a0d-a7bb-48d4-ad75-bf9dd473334b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="ddeacc7e-02cc-4027-87bc-90f4d3cd9716")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="ae2d5661-7878-492f-96bf-ca23b8ee6760")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="6433a13b-7cb6-4c1e-aae6-e79c7d26b039")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="898b00a3-a0cd-49de-ba5c-8a2874d325d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="239f0c0d-b48d-44ae-b2bf-68efdced8f57")>,
# ...

# %%
rank_lw=[]
for i in lw_tag:
    rank_lw.append(i.text)
rank_lw
# Out:
# ['1',
#  '2',
#  '3',
#  '6',
#  '4',
#  '5',
#  '7',
#  '9',
#  '8',
#  '-',
#  '10',
#  '11',
#  '15',
#  '14',
#  '17',
#  '-',
#  '13',
#  '18',
#  '12',
#  '-',
#  '81',
#  '22',
#  '23',
#  '25',
#  '21',
#  '16',
#  '-',
#  '20',
#  '24',
#  '30',
#  '-',
#  '26',
#  '34',
#  '-',
#  '19',
#  '33',
#  '39',
#  '43',
#  '37',
#  '36',
#  '29',
#  '31',
#  '-',
#  '32',
#  '41',
#  '-',
#  '28',
#  '35',
#  '48',
#  '53',
#  '63',
#  '50',
#  '66',
#  '27',
#  '47',
#  '-',
#  '42',
#  '-',
#  '51',
#  '-',
#  '56',
#  '49',
#  '68',
#  '45',
#  '38',
#  '55',
#  '-',
#  '-',
#  '72',
#  '-',
#  '-',
#  '70',
#  '-',
#  '57',
#  '60',
#  '59',
#  '54',
#  '71',
#  '-',
#  '-',
#  '69',
#  '58',
#  '77',
#  '52',
#  '73',
#  '85',
#  '78',
#  '61',
#  '75',
#  '86',
#  '87',
#  '64',
#  '74',
#  '79',
#  '76',
#  '93',
#  '89',
#  '92',
#  '-',
#  '67']

# %%
peak_tag=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
peak_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="56e85f12-e78f-446f-9860-db57177dbba0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="5210b195-1d9b-4aef-86a6-2449f7077aa8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="1b5ae766-780f-4e62-9122-ae0a845bc91f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="8af8adc7-17bc-4011-ac6c-e2bd7048b87a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="1a3eba13-4750-45bb-85d0-d80207d2a0bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="14a31b2a-350f-465b-bf9c-deec73163fce")>,
# ...

# %%
Peak_rank=[]
for i in peak_tag:
    Peak_rank.append(i.text)
Peak_rank
# Out:
# ['1',
#  '1',
#  '2',
#  '1',
#  '1',
#  '1',
#  '5',
#  '6',
#  '3',
#  '10',
#  '1',
#  '8',
#  '2',
#  '1',
#  '1',
#  '16',
#  '1',
#  '18',
#  '9',
#  '20',
#  '21',
#  '14',
#  '17',
#  '24',
#  '3',
#  '16',
#  '27',
#  '15',
#  '1',
#  '1',
#  '31',
#  '20',
#  '33',
#  '34',
#  '12',
#  '33',
#  '2',
#  '38',
#  '37',
#  '36',
#  '12',
#  '20',
#  '43',
#  '31',
#  '9',
#  '46',
#  '2',
#  '13',
#  '31',
#  '50',
#  '51',
#  '50',
#  '53',
#  '14',
#  '47',
#  '56',
#  '24',
#  '58',
#  '51',
#  '60',
#  '56',
#  '32',
#  '63',
#  '7',
#  '19',
#  '18',
#  '67',
#  '68',
#  '69',
#  '70',
#  '71',
#  '70',
#  '73',
#  '32',
#  '10',
#  '26',
#  '31',
#  '62',
#  '79',
#  '80',
#  '69',
#  '11',
#  '77',
#  '29',
#  '65',
#  '78',
#  '38',
#  '33',
#  '75',
#  '68',
#  '87',
#  '64',
#  '67',
#  '11',
#  '1',
#  '93',
#  '73',
#  '79',
#  '99',
#  '12']

# %%
wob_tag=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
wob_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="56e85f12-e78f-446f-9860-db57177dbba0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="7b87f10d-6e83-4ac7-bebc-27105ce3e1c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="5210b195-1d9b-4aef-86a6-2449f7077aa8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="1b5ae766-780f-4e62-9122-ae0a845bc91f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="8af8adc7-17bc-4011-ac6c-e2bd7048b87a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe7fe8e2bfd8f9f0eb0b3680fd9fc293", element="1a3eba13-4750-45bb-85d0-d80207d2a0bb")>,
# ...

# %%
Weeks_on_board=[]
for i in wob_tag:
    Weeks_on_board.append(i.text)
Weeks_on_board
# Out:
# ['1',
#  '3',
#  '1',
#  '2',
#  '1',
#  '1',
#  '1',
#  '5',
#  '6',
#  '3',
#  '10',
#  '1',
#  '8',
#  '2',
#  '1',
#  '1',
#  '16',
#  '1',
#  '18',
#  '9',
#  '20',
#  '21',
#  '14',
#  '17',
#  '24',
#  '3',
#  '16',
#  '27',
#  '15',
#  '1',
#  '1',
#  '31',
#  '20',
#  '33',
#  '34',
#  '12',
#  '33',
#  '2',
#  '38',
#  '37',
#  '36',
#  '12',
#  '20',
#  '43',
#  '31',
#  '9',
#  '46',
#  '2',
#  '13',
#  '31',
#  '50',
#  '51',
#  '50',
#  '53',
#  '14',
#  '47',
#  '56',
#  '24',
#  '58',
#  '51',
#  '60',
#  '56',
#  '32',
#  '63',
#  '7',
#  '19',
#  '18',
#  '67',
#  '68',
#  '69',
#  '70',
#  '71',
#  '70',
#  '73',
#  '32',
#  '10',
#  '26',
#  '31',
#  '62',
#  '79',
#  '80',
#  '69',
#  '11',
#  '77',
#  '29',
#  '65',
#  '78',
#  '38',
#  '33',
#  '75',
#  '68',
#  '87',
#  '64',
#  '67',
#  '11',
#  '1',
#  '93',
#  '73',
#  '79',
#  '99',
#  '12']

# %%
driver.close()

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
#
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
url='https://www.naukri.com/hr-recruiters-consultants'

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
search_tag=driver.find_element_by_name('qp')
search_tag
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="7236bc2b-2472-4d93-b800-f1262da560d7")>

# %%
search_tag.send_keys('Data Science')

# %%
search_btn=driver.find_element_by_id('qsbFormBtn')
search_btn.click()

# %%
name_tag=driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
name_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="3c4886e2-a953-47be-8f56-4536a9b85e97")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="85166a11-bbac-4777-861b-e7c5fcb6391b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="efeac23b-555c-4022-bad4-542caaf7286d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="bce82bd1-a62e-4ef9-920c-9f1797fb0f52")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="7c2bfe5a-dbe9-4a52-8f37-157fcb4cf511")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="d6a29636-f981-46d7-92d6-09f12113ea12")>,
# ...

# %%
Name=[]
for i in name_tag:
    Name.append(i.text)
Name
# Out:
# ['Aakash Harit',
#  'shravan Kumar Gaddam',
#  'MARSIAN Technologies LLP',
#  'Anik Agrawal',
#  'subhas patel',
#  'Abhishek - Only Analytics Hiring - India and',
#  'Institute for Financial Management and Resear',
#  'Balu Ramesh',
#  'Asif Lucknowi',
#  'InstaFinancials',
#  'Kalpana Dumpala',
#  'Mubarak',
#  'Kushal Rastogi',
#  'Ruchi Dhote',
#  'Mahesh Babu Channa',
#  'Kapil Devang',
#  'Manisha Yadav',
#  'Riya Rajesh',
#  'Rashmi Bhattacharjee',
#  'Faizan Kareem',
#  'Rithika dadwal',
#  'Azahar Shaikh',
#  'Sandhya Khandagale',
#  'Shaun Rao',
#  'Manas',
#  'kumar',
#  'Sunil Vedula',
#  'Rajat Kumar',
#  'Priya Khare',
#  'Dhruv Dev Dubey',
#  'Jayanth N',
#  'SREEDHAR',
#  'Radha Manivasagam',
#  'Prateek Kumar',
#  'Amit Sharma',
#  'Kanan',
#  'Shashikant Chaudhary',
#  'Brad',
#  'Rutuja Pawar',
#  'Madhusudhan Sridhar',
#  'Ankit Sinha',
#  'Gaurav Chouhan',
#  'Rashi Kacker',
#  'Ashwini',
#  'Balaji Kolli',
#  'Rajani Nagaraj',
#  'ROHIT Kumar',
# ...

# %%
Designation_tag=driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
Designation_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="0c33f1d9-8fa7-4dc8-a6d6-9ded405589ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="eb463c4e-02f7-4d24-b748-b600e53d094f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="19c113d8-5caf-4ed3-a2bb-514bc2a3b7e0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="ba9b2551-e13e-46d3-9dfd-a2806f2d3f65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="90703d8f-9435-4a22-9434-f58fed47ff88")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="e04c4395-824d-4a29-a350-fa9c588bca24")>,
# ...

# %%
Designation=[]
for i in Designation_tag:
    Designation.append(i.text)
Designation
# Out:
# ['HR Manager',
#  'Company Recruiter',
#  'Company HR',
#  'Company Recruiter',
#  'Founder CEO',
#  'Recruitment Lead Consultant',
#  'Programme Manager',
#  'HR Administrator',
#  'Director',
#  'Human Resource',
#  'Executive Hiring',
#  'Company HR',
#  'Company HR',
#  'Senior Executive Talent Acquisition',
#  'HR Team Lead',
#  'HR Manager',
#  'HR Executive',
#  'Manager Talent Acquisition',
#  'HR Head',
#  'HR MANAGER',
#  'HR Recruiter',
#  'Company Recruiter',
#  'HR Recruiter',
#  'Manager Human Resources',
#  'Lead Talent acquisition',
#  'Proprietor',
#  'CEO',
#  'Founder CEO',
#  'Senior Manager',
#  'Company Recruitment Head',
#  'Project Manager',
#  'Recruitment Consultant',
#  'HR Executive',
#  'Head',
#  'Consultant',
#  'senior technology instructor',
#  'HR Recruiter/HR Excutive',
#  'Manager, Technical Recruiting',
#  'Technical Recruiter',
#  'Erp Implementer',
#  'Head Analytics',
#  'Chief Technical Officer',
#  'Sr Product Manager',
# ...

# %%
company_tag=driver.find_elements_by_xpath("//a[@class='ellipsis']")
company_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="ea87335c-b63a-488a-89ea-6fc096bc58c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="6c6e76ea-c808-44bb-aa7a-09a0f10e260f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="d5795cc5-d636-45d1-a536-74a65fc1ebc1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="e8e0a55e-0143-44b6-b89e-dcea16739415")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="9bf6d742-32ef-47a9-b5b9-db0a5f96152f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="3591a870-56ed-4103-a282-972718d3682e")>,
# ...

# %%
Company=[]
for i in company_tag:
    Company.append(i.text)
Company
# Out:
# ['Aakash Harit',
#  'Data Science Network',
#  'shravan Kumar Gaddam',
#  'Shore Infotech India Pvt. Ltd',
#  'MARSIAN Technologies LLP',
#  'MARSIAN Technologies LLP',
#  'Anik Agrawal',
#  'Enerlytics Software Solutions Pvt Ltd',
#  'subhas patel',
#  'LibraryXProject',
#  'Abhishek - Only Analytics Hiring - India and',
#  'Apidel Technologies Division of Transpower',
#  'Institute for Financial Management and Resear',
#  'IFMR',
#  'Balu Ramesh',
#  'Techvantage Systems Pvt Ltd',
#  'Asif Lucknowi',
#  'Weupskill- Live Wire India',
#  'InstaFinancials',
#  'CBL Data Science Private Limited',
#  'Kalpana Dumpala',
#  'Innominds Software',
#  'Mubarak',
#  'MoneyTap',
#  'Kushal Rastogi',
#  'QuantMagnum Technologies Pvt. Ltd.',
#  'Ruchi Dhote',
#  'Bristlecone India Ltd',
#  'Mahesh Babu Channa',
#  'SocialPrachar.com',
#  'Kapil Devang',
#  'BISP Solutions',
#  'Manisha Yadav',
#  'Easi Tax',
#  'Riya Rajesh',
#  'Novelworx Digital Solutions',
#  'Rashmi Bhattacharjee',
# ...

# %%
skills_tag=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
skills_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="85d257c4-4823-4783-81ee-bac0f4594c4d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="57d20534-9ae5-4ed1-97ba-57b8a1e55603")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="dce8e671-d970-4269-a688-b44410da1c7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="49a359c4-337a-4422-835e-67f1eb9bca2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="0ef1b988-d802-48c2-a4d6-d4fe9ab56ddf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="84fb37c1-2786-4ac9-b3a6-3b13a7971325")>,
# ...

# %%
skills=[]
for i in skills_tag:
    skills.append(i.text)
skills
# Out:
# ['Classic ASP Developer, Internet Marketing Professional, Data Science SME, Content Writers, SEO Professional, Revenue Professional',
#  '.Net, Java, Data Science, Linux Administration, Sql Server Development, Winforms, Wcf Services, Wpf, Telecom Engineering, Technical Management, Software',
#  'Data Science, Artificial Intelligence, Machine Learning, Business Analytics',
#  'Mean Stack, javascript, angularjs, mongodb, Web Services, rest, express, Node.js, Big Data, iot, Data Science, Cloud Computing, saas, Aws',
#  'Hadoop, Spark, Digital Strategy, Data Architecture, Command Center, Cdp, Dmp, Kafka, Data Science, Data Analysis, Big Data Analytics, Real Time Analysis, SQL',
#  'Analytics, Business Intelligence, Business Analytics, Predictive Modeling, Predictive Analytics, Data Science, Data Analysis, Data Analytics, Big Data, Big',
#  'Data Science',
# ...

# %%
loc_tag=driver.find_elements_by_xpath("//small[@class='ellipsis']")
loc_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="b8b9768c-11e6-422b-83e5-c1b58d5bd3d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="cf3b3be2-be22-42d3-974d-5d6b3ad204a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="91c00c37-f59a-4c17-a02b-f752711ab6cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="a3c688e8-b88e-4500-b8a6-d1c8299f5fa6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="87cc855c-4113-4f42-ba5b-acb88b1a6d64")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="55d2da466c17345253142a63fffd3441", element="6d0193df-9bdb-4386-8458-cf4cebc19cf8")>,
# ...

# %%
Location=[]
for i in loc_tag:
    Location.append(i.text)
Location
# Out:
# ['Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Ahmedabad',
#  'UK - (london)',
#  'Vadodara / Baroda',
#  'Chennai',
#  'Trivandrum',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Pune',
#  'Hyderabad / Secunderabad',
#  'Bhopal',
#  'Navi Mumbai',
#  'Cochin',
#  'Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'Delhi',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'Mysoru / Mysore',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Noida',
#  'New Delhi',
#  'Chennai',
#  'Aligarh',
#  'Salt Lake City',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'MYSORE',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Noida',
#  'Mumbai']

# %%
driver.close()

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey%02compare/'

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
Error is coming whiile scraping

# %%
driver.close()

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
url='https://www.imdb.com/list/ls095964455/'

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
tag_1=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
tag_1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="aac36e31-ce74-48da-8907-9ad9b3b16327")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="e86b02d2-c2ee-47c5-8757-c0ee87e75478")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="74f814b4-1f6f-498f-9846-f003e5ccb8b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="585665ef-4695-4b74-a1ad-679674590261")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="079869d0-76e4-44c6-8909-39a789eda481")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="6896142d-0417-47c4-9392-708269cb37ec")>,
# ...

# %%
Year_Span=[]
for i in tag_1:
    Year_Span.append(i.text)
Year_Span
# Out:
# ['(2011–2019)',
#  '(2016– )',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017– )',
#  '(2005– )',
#  '(2014– )',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011– )',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016– )',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016– )',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018– )',
#  '(2019– )',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2018– )',
#  '(2006–2021)',
#  '(2015– )',
#  '(1999– )',
#  '(2013– )',
#  '(2004–2010)',
#  '(2013– )',
#  '(2004–2012)',
# ...

# %%
tag_2=driver.find_elements_by_xpath("//span[@class='runtime']")
tag_2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="23496f0c-6642-42a4-ae67-fb1d87236765")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="c8a51321-ac17-4240-b9b6-8ea8759129fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="7c08345e-1ef2-4731-b16e-f573c22b1631")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="6bd26174-e58a-4134-9bea-0de7a7cd1164")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="549b3399-3784-47e3-9507-be20594cf164")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="ea74e001-9a1e-4115-93e7-f8237f540fa5")>,
# ...

# %%
Runtime=[]
for i in tag_2:
    
    Runtime.append(i.text)
Runtime
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
tag_3=driver.find_elements_by_xpath("//span[@class='genre']")
tag_3
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="e417aa4d-0c8d-4e9f-a852-00e99d587b96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="0ea4b0fb-1a55-4b86-b5fd-48dae832dd19")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="a0813122-43d0-4a0d-ad4f-ddf5b81201f2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="85f2ec5e-c67f-4d6f-972a-4c933c328cc0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="b15f4b16-93f2-4a25-bef9-37590dd3e300")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="48844a85993800d0c0c2b9359d7fa8fd", element="b4264da7-b8d1-438d-b7ac-e646401375cd")>,
# ...

# %%
Genre=[]
for i in tag_3:
    
    Genre.append(i.text)
Genre
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Mystery',
#  'Comedy, Romance',
#  'Drama, Sci-Fi, Thriller',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
# ...

# %%
driver.close()
