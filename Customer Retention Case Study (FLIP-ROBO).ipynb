# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('CSR.xlsx')
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# In the above dataset their are 269 rows and 71 columns.

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                                                                                                                                                                  object
# 2 How old are you?                                                                                                                                                                                                     object
# 3 Which city do you shop online from?                                                                                                                                                                                  object
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                   int64
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                                                                                                                                                                  object
# 2 How old are you?                                                                                                                                                                                                     object
# 3 Which city do you shop online from?                                                                                                                                                                                  object
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                   int64
# ...

# %% [markdown]
# Here, only one column is of int64 datatypes and rest of the columns are object data types.

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                                                                                                                                                                  0
# 2 How old are you?                                                                                                                                                                                                     0
# 3 Which city do you shop online from?                                                                                                                                                                                  0
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  0
# ...

# %% [markdown]
# Their are no missing values in the dataset.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# In the above dataset, the Gender count for male is 88 and for female the count is 181.

# %%
df['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %% [markdown]
# Highest number of people are in age group of 31-40 years and lowest number of people are in the age group of 51 years and above.

# %%
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# Most of the people do shop online from Delhi and least from Bulandshahr.

# %%
df['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# Maximum number of people shopping online from last 4 Years.

# %%
df['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %% [markdown]
# Their are only 6 people did online shopping 42 times and above in the past 1 year, as their are 114 people who did online shopping less than 10 times in past 1 year.

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# Their are 189 people who used mobile internet and their are 76 people who used wifi and 4 people who used Dial up.

# %%
df['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# Their are 141 users with Smartphone, 86 users with laptop, 30 users with desktop and 12 users have Tablet, as a device for online shopping.

# %%
df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %% [markdown]
# 122 people have windows/windows mobile as their operating system, 85 have Android as their OS and 62 have IOS/Mac as thier OS.

# %%
df[ '11 What browser do you run on your device to access the website?\t\t\t                                                          '].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %% [markdown]
# Number of people who uses Google Chrome - 216
#
# Number of people who uses Safari - 40
#
# Number of people who uses Opera - 8
#
# Number of people who uses Mozilla - 5

# %%
df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %% [markdown]
# CHANNEL:-
#
# 230 people follow Search Engine as their favourite online store.
#
# 20 People follow Content Marketing as thier Favourite online Store.
#
# 19 people follow Display Adverts as their Favourite Online store.

# %%
df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %% [markdown]
# After first Visit:-
#
#     87 People reach the online store by search engine.
#
#     86 People via Application.
#
#     70 people via Direct URl
#
#     8 people by Social Media.

# %%
df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %% [markdown]
# 148 People preferred Credit/Debit card as a Payment option.
#
# 76 People Preferred COD as a mode of Payment.
#
# 45 People preffered Ewallet as their PAyment Option.

# %%
df['18 The content on the website must be easy to read and understand'].head()
# Out:
# 0             Agree (4)
# 1    Strongly agree (5)
# 2    Strongly agree (5)
# 3             Agree (4)
# 4    Strongly agree (5)
# Name: 18 The content on the website must be easy to read and understand, dtype: object

# %%
df['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
sns.countplot(df['18 The content on the website must be easy to read and understand'])
# Out:
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %% [markdown]
# 80 People completely agree on that The content on the website must be easy to read and understand.  (Rating 4).
#
# 164 People are strongly agree onthat The content on the website must be easy to read and understand. (Rating 5)
#
# 18 People are strongly disagree on that The content on the website must be easy to read and understand. (Rating 1)
#
#  people are there with Neutral rating as 3.

# %%
df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
sns.countplot(df['20 Complete information on listed seller and product being offered is important for purchase decision.'])
# Out:
# <AxesSubplot:xlabel='20 Complete information on listed seller and product being offered is important for purchase decision.', ylabel='count'>

# %% [markdown]
# Number of People who agree on the fact that Complete information on listed seller and product being offered is important for purchase decision are 101
#
# Number of People who strongly agree on the fact that Complete information on listed seller and product being offered is important for purchase decision are 87
#
# Number of People who are indifferent on the fact that Complete information on listed seller and product being offered is important for purchase decision are 52
#
# Number of People who disagree on the fact that Complete information on listed seller and product being offered is important for purchase decision are 18
#
# Number of People who are strongly disagree on the fact that Complete information on listed seller and product being offered is important for purchase decision are 11.

# %%
df['21 All relevant information on listed products must be stated clearly'].value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %%
sns.countplot(df['21 All relevant information on listed products must be stated clearly'])
# Out:
# <AxesSubplot:xlabel='21 All relevant information on listed products must be stated clearly', ylabel='count'>

# %% [markdown]
# 132 people agrees that the relevant information on listed products is clearly stated.
#
# 107 people strongly agrees that the relevant information on listed products is clearly stated.
#
# 18 people Dis-agrees that the relevant information on listed products is clearly stated.
#
# 12 People are their with indifferent opinion.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df['23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %% [markdown]
# 115 people strongly agree on the fact that Loading and processing speed were good.
#
# 112 people agree on the fact that Loading and processing speed were good.
#
# 18 people dis-agree on the fact that Loading and processing speed were good.
#
# 12 people strongly disagree on the fact that Loading and processing speed were good.
#
# 12 people have neutral opinion.

# %%
df['24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %% [markdown]
# 189 number of people strongly believes that interface of the website is user friendly.
#
# 45 number of people agrees that interface of the website is user friendly.
#
# 18 people are strongly disatisfied with the Interface.
#
# 12 people are dissatisfied with the interface.
#
# Number of people who have neutral opinion are 5.

# %%
df['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %% [markdown]
# People who strongly agree that the payment methods are convinient are 159.
#
# People who agrees that the payment methods are convinient are 80.
#
# People who are disagree with the payment methods are 30.

# %%
df['31 Enjoyment is derived from shopping online'].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %% [markdown]
# Number of people who strongly believes in the thing that Enjoyment is derived from shopping online are 86.
#
# Number of people who strongly dis-agree in the thing that Enjoyment is derived from shopping online are 30.

# %%
df[ '33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %% [markdown]
# 98 nmumber of people strongly believes that the Return and replacement policy of the e-tailer is important for purchase decision.
#
# 20 nmumber of people dis-agrees the fact that Return and replacement policy of the e-tailer is important for purchase decision.

# %%
df['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %% [markdown]
# 33 number of people Strongly agrees the fact that the  Displaying quality Information on the website improves satisfaction of customers.
#
# 56 number of people have Neutral opinion.

# %%
df['38 User satisfaction cannot exist without trust'].value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %% [markdown]
# The count of people who Strongly agree that the fact  User satisfaction cannot exist without trust are 122.
#
# The count of people who Strongly dis-agree that the fact  User satisfaction cannot exist without trust are 18.
#
#  people have neutral opinion.

# %%
df['39 Offering a wide variety of listed product in several category']
# Out:
# 0         indifferent (3)
# 1      Strongly agree (5)
# 2      Strongly agree (5)
# 3               Agree (4)
# 4               Agree (4)
# 5      Strongly agree (5)
# 6               Agree (4)
# 7      Strongly agree (5)
# 8      Strongly agree (5)
# 9               Agree (4)
# 10        indifferent (3)
# 11        indifferent (3)
# 12     Strongly agree (5)
# 13              Agree (4)
# 14     Strongly agree (5)
# 15              Agree (4)
# 16              Agree (4)
# 17     Strongly agree (5)
# 18              Agree (4)
# 19              Agree (4)
# 20              Agree (4)
# 21     Strongly agree (5)
# 22     Strongly agree (5)
# 23              Agree (4)
# 24        indifferent (3)
# 25        indifferent (3)
# 26     Strongly agree (5)
# 27              Agree (4)
# 28     Strongly agree (5)
# 29              Agree (4)
# 30              Agree (4)
# 31        indifferent (3)
# 32     Strongly agree (5)
# 33     Strongly agree (5)
# 34              Agree (4)
# ...

# %%
df['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %%
df['41 Monetary savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %% [markdown]
# 148 people are strongly agree with the Monetary Savings Fact.
#
# 31 people are Dis-agree with monetary savings fact.

# %%
df['47 Getting value for money spent'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %% [markdown]
# 149 people  Agree that they are getting value for money spent.
#
# 38 people are there with Neutral opinion.

# %%
df['Easy to use website or application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com                                         44
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %% [markdown]
# 64 People thinks that Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com  are the websites or applications to use combinely.

# %%
df['Complete, relevant description information of products'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %% [markdown]
# According to 100 customers, the proper information of the product which is relevant is given by Amazon.in and Flipkart.com combinely.

# %%
df['Reliability of the website or application'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Flipkart.com                                         15
# Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %% [markdown]
# Amazon.in is more reliable individually as by 61 customers.
#
# Paytm.com is least reliable individually compared to others.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df['Quickness to complete purchase'].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Flipkart.com                                                 15
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %% [markdown]
# According 64 customers, that is maximum, are happy via using amazon.in for quickness to complete purchase as compare to others.

# %%
df['Availability of several payment options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %% [markdown]
# Amazon.in and Flipkart.com combinely have availability of several payment options as told by 65 customers.

# %%
df['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Flipkart.com                               15
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %% [markdown]
# Amazon.in has been voted highest as the fastest order delivery by 107 customers.

# %%
df['Privacy of customers’ information'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Amazon.in, Paytm.com                                            15
# Flipkart.com                                                    15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %% [markdown]
# Amazon.in individually rated by 71 customers as it keeps privacy of customers information as compare to others.

# %%
df['Security of customer financial information'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Paytm.com                                                       15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %% [markdown]
# Amazon.in keeps the customers financial information secure as compare to others.

# %%
df['Late declaration of price (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Amazon.in                  38
# Flipkart.com               38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %% [markdown]
# According 75 people Myntra.com declare price very late as compared to amazon.in and flipkart.com.

# %%
df['Longer page loading time (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %% [markdown]
# Myntra.com takes more time to load the page individually as compre with others.

# %%
df['Longer delivery period'].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period, dtype: int64

# %% [markdown]
# Paytm.com takes longer time to deliver products as Myntra.com takes least time to deliver the products.

# %%
df['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# Most of the customers recommending Amazon to their friend as comapre to others Indian Online Retailers.

# %%
sns.set_style('whitegrid')
sns.countplot(x='2 How old are you? ',hue='1Gender of respondent',data=df)
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# for the age group of 31-40 years, 21-30 years, 41-50 years, less than 20 years, 51 years and above, most of the customers are Female as compair to male gender.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='3 Which city do you shop online from?',hue='1Gender of respondent',data=df)
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %%
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# More numbers  of Male customers are their in Delhi and Karnal as compair to female Customers and for rest of the cities Female customers are more.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='5 Since How Long You are Shopping Online ?',hue='2 How old are you? ',data=df)
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# People in the age range of 31-40 years doing online shopping from more than 4 years, while the count is less for people whose age is 5 years and above.
#
# People in the age group 21-30 years, shopping online from 3-4 years and count is less for 51 years and above.
#
# People who are in age group 41-50years, are mostly doing shopping online from 2-3 years.
#
# People who are in the age range 31-40 years are doing online shopping from less than 1 year.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='5 Since How Long You are Shopping Online ?',hue='1Gender of respondent',data=df)
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# More Female customers are shoppinmg online for above 4 years range, 2-3 years range, less than 1 year and 1-2 years range. Only for 3-4 years range, Male customers are more who did online shopping as compair to female customers.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='8 Which device do you use to access the online shopping?',hue='1Gender of respondent',data=df)
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %% [markdown]
# Desktop, Smartphone and laptop were more used by female customers as compair with male customers, and tablet were used by Male cutomers only.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='10 What is the operating system (OS) of your device?\t\t\t\t                                          ',hue='2 How old are you? ',data=df)
# Out:
# <AxesSubplot:xlabel='10 What is the operating system (OS) of your device?\t\t\t\t                                          ', ylabel='count'>

# %% [markdown]
# For the age range of 31-40 years, Windows/windows mobile users are the highest and lowest for the age group of the customers who are less than 20 years.
#
# 21-30 years of people mostly prefer IIOS/Mac as their OS.
#
# Android as OS mostly used by Customers who are in age range of 21-30 years.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='10 What is the operating system (OS) of your device?\t\t\t\t                                          ',hue='1Gender of respondent',data=df)
# Out:
# <AxesSubplot:xlabel='10 What is the operating system (OS) of your device?\t\t\t\t                                          ', ylabel='count'>

# %% [markdown]
# All the three Operating Systems are miostly used by Female Customers as compare with Male Customers.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ',hue='1Gender of respondent',data=df)
# Out:
# <AxesSubplot:xlabel='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ', ylabel='count'>

# %% [markdown]
# Above payment methods are mostly used by Female customers as compare with Male Customers.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x= '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ',hue='1Gender of respondent',data=df)
# Out:
# <AxesSubplot:xlabel='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ', ylabel='count'>

# %% [markdown]
# As per the above data, in all the categories, Most of the Female customers frequently abandon their shopping cart as compair with male customers.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ']
# Out:
# 0                     Lack of trust
# 1         Promo code not applicable
# 2         Promo code not applicable
# 3          Better alternative offer
# 4          Better alternative offer
# 5          Better alternative offer
# 6         Promo code not applicable
# 7                   Change in price
# 8      No preferred mode of payment
# 9                     Lack of trust
# 10                  Change in price
# 11         Better alternative offer
# 12         Better alternative offer
# 13         Better alternative offer
# 14        Promo code not applicable
# 15         Better alternative offer
# 16         Better alternative offer
# 17         Better alternative offer
# 18        Promo code not applicable
# 19         Better alternative offer
# 20         Better alternative offer
# 21                  Change in price
# 22     No preferred mode of payment
# 23                    Lack of trust
# 24                  Change in price
# 25         Better alternative offer
# ...

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='18 The content on the website must be easy to read and understand',hue='2 How old are you? ',data=df)
# Out:
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %% [markdown]
# People in the age group 31-40 are agree with the fact that the content on the website must be easy to read and understand as compaire with other age groups.
#
# People in the age group 41-50 years are strongly dis-agree with the fact that the content on the website must be easy to read and understand.
#
# Customers whose age is less than 20 years have most of the neutral opinions.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x= '20 Complete information on listed seller and product being offered is important for purchase decision.',hue='2 How old are you? ',data=df)
# Out:
# <AxesSubplot:xlabel='20 Complete information on listed seller and product being offered is important for purchase decision.', ylabel='count'>

# %% [markdown]
# Customers in the age group of 31-40 years and 21-30 years have most of the indifferent opinions.
#
# Customers in the age group of 41-50 years are strongly agree mostly that the Complete information on listed seller and product being offered is important for purchase decision.
#
# Although Customers in the age group of 31-40 years are strongly dis-agree mostly that the Complete information on listed seller and product being offered is important for purchase decision.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x=  '25 Convenient Payment methods',hue='2 How old are you? ',data=df)
# Out:
# <AxesSubplot:xlabel='25 Convenient Payment methods', ylabel='count'>

# %% [markdown]
# People in the age group of 21-40 strongly agrees that the Payment methoda are convinient.
#
# People in the age group of 41-50 years dis-agree that the payment methods are convinient mostly.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='27 Empathy (readiness to assist with queries) towards the customers',hue='2 How old are you? ',data=df)
# Out:
# <AxesSubplot:xlabel='27 Empathy (readiness to assist with queries) towards the customers', ylabel='count'>

# %% [markdown]
# Customers in the age group 31-40 years strongly agrees with term empathy mostly as compair with other age groups.
#
# Customers in the age group 41-50 years strongly dis-agrees with the term empathy mostly.
#
# Customers in the age group 31-40 years have most of the indifferent opinion regarding empathy.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='30 Online shopping gives monetary benefit and discounts',hue='2 How old are you? ',data=df)
# Out:
# <AxesSubplot:xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='count'>

# %% [markdown]
# Most of the customers in the age-group of 21-30 years strongly agrees that the Online shopping gives monetary benefit and discounts as compare with other age groups.
#
# Most of the customers in the age-group of 41-50 years strongly dis-agrees that the Online shopping gives monetary benefit and discounts as compare with other age groups.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='31 Enjoyment is derived from shopping online',hue='1Gender of respondent',data=df)
# Out:
# <AxesSubplot:xlabel='31 Enjoyment is derived from shopping online', ylabel='count'>

# %% [markdown]
# For Strongly Dis-agree rating, both male and Female customers have same opinion.
#
# For other categories, like, strongly agree, indifferent, agree and dis-agree Female customers have maximum opinions.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='38 User satisfaction cannot exist without trust',hue='2 How old are you? ',data=df)
# Out:
# <AxesSubplot:xlabel='38 User satisfaction cannot exist without trust', ylabel='count'>

# %% [markdown]
# Most of the customers in the age group of 31-40 years Strongly agree with the fact that User satisfaction cannot exist without trust.
#
# Most of the customers in the age group of 41-50 years Strongly dis-agree with the fact that User satisfaction cannot exist without trust.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='44 Shopping on your preferred e-tailer enhances your social status',hue='2 How old are you? ',data=df)
# Out:
# <AxesSubplot:xlabel='44 Shopping on your preferred e-tailer enhances your social status', ylabel='count'>

# %% [markdown]
# Most of the customers from the age group 31-40 years having indiffernt opinion and even dis-agrees as compare to others.
#
# Most of the customers from the age group 21-30 years strongly agrees with the fact that Shopping on your preferred e-tailer enhances your social status.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='47 Getting value for money spent',hue='2 How old are you? ',data=df)
# Out:
# <AxesSubplot:xlabel='47 Getting value for money spent', ylabel='count'>

# %% [markdown]
# Most of the customers from the age group 31-40 years Strongly agrees with the fact that they are Getting value for money spent.
#
# Most of the customers from the age group 21-30 have indifferent opinion.

# %%
plt.figure(figsize=[14,6])
sns.set_style('whitegrid')
sns.countplot(x='2 How old are you? ',hue='Easy to use website or application',data=df)
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# Most of the Customers from the age group of 31-40 years find Amazon, Flipkart,paytm, Myntra and Snapdeal combinely as easy to use websites/applicationsas compare to others.
#
# Most of the Customers from the age group of 21-30 years find Amazon, Flipkart,paytm, Myntra and Snapdeal combinely as easy to use websites/applicationsas compare to others.
#
# Most of the customers from age group of 41-50 years find Amazon and flipkart combinely and Amazon individually as easy to use website or application.
#
# Most of the customers in the age group of less than 20 years have find amazon, flipkart, myntra and snapdeal combinely as easy to use websie/application.
#
# Most of the customers in the age group of less than 51 years and above have find amazon, flipkart, myntra and snapdeal combinely as easy to use websie/application.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
plt.figure(figsize=[14,6])
sns.set_style('whitegrid')
sns.countplot(x='1Gender of respondent',hue='Easy to use website or application',data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# Most of Male customers find Amazon,flipkart,paytm and snapdeal combinely as easy to use website/application.
#
# Most of the Female customers find amazon, myntra, flipkart, paytm and snapdeal combinely as easy to use website/application.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='1Gender of respondent',hue='Complete, relevant description information of products',data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# Most of the customers from male and female categories thinks that Amazon and Flipkart combinely gives Complete, relevant description information of products as comapre to others.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='1Gender of respondent',hue='Reliability of the website or application',data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# Most of the male customers find Amazon, Flipkart and Paytm combinely as most reliable websites/applications.
#
# Most of the female customers find amazon  as most reliable website/application.

# %%
plt.figure(figsize=[14,6])
sns.set_style('whitegrid')
sns.countplot(x='2 How old are you? ',hue='Quickness to complete purchase',data=df)
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# Maximum Customers in the age group of 31-40 years thinks that Their is quickness to complete purchase on Amazon and Flipkart combinely.
#
# Maximum Customers in the age group of 21-30 years and 41-50 years thinks that Their is quickness to complete purchase on Amazon.
#
# Maximum Customers in the age group of less than 20 years think that Their is quickness to complete purchase on Myntra,Flipkart and snapdeal. combinely.
#
# Maximum Customers in the age group of 51 years and above think that Their is quickness to complete purchase on Myntra,Flipkart and Amazon.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='1Gender of respondent',hue='Speedy order delivery ',data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# According to both the genders, i.e, Male and Female both, Amazon.in delivers the product very fast.
#
# According to Female Customers, Flipkart, Myntra and Snapdeal combinely did not delivers the product fast.

# %%
plt.figure(figsize=[14,6])
sns.set_style('whitegrid')
sns.countplot(x='2 How old are you? ',hue='Privacy of customers’ information',data=df)
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# Maximum customers from the age group of 31-40 years reviewed that the Amazon and Flipkart keeps the information of customer private.
#
# Maximum customers from the age group of 21-30 years reviewed that the Amazon.in keeps the information of customer private as compared to others.
#
# Maximum customers from the age group of 41-50 years and even 51 years and above reviewed that the Amazon.in keeps the information of customer private as compared to others.

# %%
plt.figure(figsize=[14,6])
sns.set_style('whitegrid')
sns.countplot(x='2 How old are you? ',hue='Security of customer financial information',data=df)
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# Maximum Customers from the age group of 31-40 years reviewed that Flipkart.com keeps their financial information secure as compare to others.
#
# Maximum Customers from the age group of 21-30 years, 41-50 years and 51 years and above age group reviewed that Amazon.in keeps their financial information secure as compare to others.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='1Gender of respondent',hue='Longer time to get logged in (promotion, sales period)',data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# According to male customers flipkart and paytm takes less time to logged in.
#
# According to female customers amazon and Paytm takes the least time to logged in.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='1Gender of respondent',hue='Frequent disruption when moving from one page to another',data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# snapdeal.com got the higheest votes for the above category acoording to female customers.
#
# Amazon.com got the higheest votes for the above category acoording to female customers.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='1Gender of respondent',hue='Which of the Indian online retailer would you recommend to a friend?',data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# According to above observation,  Male Customersand Female Customers, both will recommend Amazon.in to their friend as the Indian Online Retailer.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='2 How old are you? ',hue='Which of the Indian online retailer would you recommend to a friend?',data=df)
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# Most of the customers in the age group of 31-40 years would recommend Flipkart.com to their friend as compare to their friend.
#
# Most of the customers in the age group of 21-30 years would recommend Amazon and Flipkart.com to their friend as compare to their friend.
#
# Most of the customers in the age group of 41-50 years would recommend amazon.in to their friend as compare to others.
#
# Most of the customers in the age group of less than 20 years would recommend amazon.in to their friend as compare to others.

# %%
plt.figure(figsize=[12,6])
sns.set_style('whitegrid')
sns.countplot(x='3 Which city do you shop online from?',hue='Which of the Indian online retailer would you recommend to a friend?',data=df)
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# Most of the customers from Delhi,Greater Noida, Karnal recommended Amazon and Flipkart to their friend as compare to other Indian Online Retailers.
#
# Most of the customers from Banglore, Noida, Solan, Moradabad, Merut, Ghaziabad and Bulandshahr recommended Amazon to their friend as compare to other Indian Online Retailers.
