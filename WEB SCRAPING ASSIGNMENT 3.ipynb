# %% [markdown]
# 1. Write a python program which searches all the product under a particular product vertical
# from www.amazon.in. The product verticals to be searched will be taken as input from user.
# For e.g. If user input is ‘guitar’. Then search for guitars.
#
#
# 2. In the above question, now scrape the following details of each product listed in first 3 pages
# of your search results and save it in a dataframe and csv. In case if any product vertical has
# less than 3 pages in search results then scrape all the products available under that product
# vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of
# Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details"
# and “Product URL”. In case, if any of the details are missing for any of the product then
# replace it by “-“.

# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get("https://www.amazon.in/")

# %%
#finding element for searchbar

search=driver.find_element_by_id('twotabsearchtextbox')
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6c15b2bf17f479ecfa6442911ae1fac0", element="e887f50f-9157-4127-a8a6-734a7d0b10bc")>

# %%
search.send_keys('shoes')

# %%
search_btn=driver.find_element_by_id('nav-search-submit-button')
search_btn.click()

# %%
btn=driver.find_element_by_xpath("//span[@class='a-size-base-plus a-color-base a-text-normal']")

# %%
btn.click()

# %%
#Fetching urls

urls=[]
for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):
    urls.append(i.get_attribute("href"))
    
urls
# Out:
# ['https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A0276491AAKIDJHJ716K&url=%2FBourge-Vega-6-Running-Shoes-6-Vega-6-06%2Fdp%2FB07V1VJMPT%2Fref%3Dsr_1_1_sspa%3Fdchild%3D1%26keywords%3Dshoes%26qid%3D1622214865%26sr%3D8-1-spons%26psc%3D1&qualifier=1622214865&id=3431983301656011&widgetName=sp_atf',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A03764432WWGDS1G9K3E1&url=%2FASIAN-Bouncer-01-Stylish-Sneakers-Lightweight%2Fdp%2FB08H12NBVH%2Fref%3Dsr_1_2_sspa%3Fdchild%3D1%26keywords%3Dshoes%26qid%3D1622214865%26sr%3D8-2-spons%26psc%3D1&qualifier=1622214865&id=3431983301656011&widgetName=sp_atf',
# ...

# %%
#Defining variables
Product_Name_1=[]
Price_1=[]
No_Rating_1=[]
Ratings=[]

# %%
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #fetching for Brand Name
    try:
        product=driver.find_element_by_id('productTitle')
        Product_Name_1.append(product.text)
        
    except NoSuchElementException:
        Product_Name_1.append('-')

# %%
Product_Name_1
# Out:
# ["Bourge Men's Vega Pearl-z2 Running Shoes",
#  "ASIAN Men's Bouncer-01 Sports Latest Stylish Casual Sneakers,Lace up Lightweight Shoes for Running, Walking, Gym",
#  "ASIAN Men's Airsocks-12 Black Red Knitted Sports Shoes",
#  "ASIAN Men's Running Shoes",
#  'Bersache Combo Pack of 3,Sports Running Shoe for Men',
#  'CLYMB Outdoor Sports Running Shoes for Mens Boy',
#  "White Walkers Men's & Boys Multicolor Running Casual Sports Shoes",
#  "ASIAN Men's Wonder-13 Sports Running Shoes",
#  'TRASE Running Shoes for Men Sports',
#  "Bourge Men's Vega Pearl-z2 Running Shoes",
#  "Sparx Men's Sd0323g Sneakers",
#  "Bourge Men's Vega-z1 Running Shoes",
#  "Sparx Women's Sx0088l Running Shoes",
#  "Bourge Men's Vega Pearl-z2 Running Shoes",
#  "Sparx Men's Sd0323g Sneakers",
#  "Campus Men's Oxyfit Running Shoes",
#  "T-Rock Men's Mesh Sports Running Shoes",
#  "WORLD WEAR FOOTWEAR Men's (9228-9303-9098) Casual Sports Running Shoes",
#  "Sparx Men's Sm-651 Running Shoe",
# ...

# %%
len(Product_Name_1)
# Out:
# 69

# %%
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #fetching price
    try:
        price=driver.find_element_by_xpath("//td[@class='a-span12']")
        Price_1.append(price.text)
        
    except NoSuchElementException:
        Price_1.append('-')

# %%
Price_1
# Out:
# ['₹ 594.00',
#  '₹ 719.00',
#  '₹ 707.00',
#  '₹ 707.00',
#  '₹ 587.00 - ₹ 649.00',
#  '₹ 299.00 - ₹ 399.00',
#  '₹ 499.00',
#  '₹ 579.00',
#  '₹ 499.00',
#  '₹ 569.00',
#  '₹ 630.00',
#  '₹ 594.00',
#  '₹ 840.00',
#  '₹ 594.00',
#  '₹ 630.00',
#  '₹ 679.00',
#  '₹ 368.00 - ₹ 600.00',
#  '₹ 699.00',
#  '₹ 795.00 - ₹ 999.00',
#  '₹ 389.00 - ₹ 999.00',
#  '₹ 958.00 - ₹ 1,349.00',
#  '₹ 339.00 - ₹ 599.00',
#  '₹ 379.00 - ₹ 429.00',
#  '₹ 949.00',
#  '₹ 459.00 - ₹ 499.00',
#  '₹ 522.00',
#  '₹ 594.00 - ₹ 699.00',
#  '₹ 807.00 - ₹ 1,049.00',
#  '₹ 399.00 - ₹ 445.00',
#  '₹ 767.00',
#  '₹ 699.00',
#  '₹ 709.00',
#  '₹ 999.00',
#  '₹ 499.00 - ₹ 750.00',
#  '₹ 569.00 - ₹ 599.00',
#  '₹ 594.00 - ₹ 649.00',
#  '₹ 523.00 - ₹ 599.00',
#  '₹ 558.00 - ₹ 749.00',
#  '₹ 1,239.00 - ₹ 1,699.00',
#  '₹ 845.00 - ₹ 978.00',
#  '₹ 719.00 - ₹ 824.00',
#  '₹ 1,619.00 - ₹ 1,799.00',
#  '₹ 399.00 - ₹ 479.00',
#  '₹ 860.00 - ₹ 1,099.00',
#  '₹ 499.00',
#  '₹ 1,599.00',
#  '₹ 499.00 - ₹ 524.00',
# ...

# %%
len(Price_1)
# Out:
# 69

# %%
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #fetching for Brand Name
    try:
        no_rat=driver.find_element_by_id('acrCustomerReviewText')
        No_Rating_1.append(no_rat.text)
        
    except NoSuchElementException:
        No_Rating_1.append('-')

# %%
No_Rating_1
# Out:
# ['22,058 ratings',
#  '1,715 ratings',
#  '791 ratings',
#  '281 ratings',
#  '88 ratings',
#  '1,196 ratings',
#  '85 ratings',
#  '34,231 ratings',
#  '4,656 ratings',
#  '22,058 ratings',
#  '8,407 ratings',
#  '8,250 ratings',
#  '4,928 ratings',
#  '22,058 ratings',
#  '8,407 ratings',
#  '6,938 ratings',
#  '3,101 ratings',
#  '24 ratings',
#  '22 ratings',
#  '390 ratings',
#  '2,740 ratings',
#  '106 ratings',
#  '180 ratings',
#  '299 ratings',
#  '3,455 ratings',
#  '7,883 ratings',
#  '5,566 ratings',
#  '205 ratings',
#  '41 ratings',
#  '302 ratings',
#  '26 ratings',
#  '355 ratings',
#  '78 ratings',
#  '34,231 ratings',
#  '548 ratings',
#  '8,250 ratings',
#  '5,395 ratings',
#  '22,058 ratings',
#  '697 ratings',
#  '3 ratings',
#  '1,715 ratings',
#  '15 ratings',
#  '649 ratings',
#  '106 ratings',
#  '4,962 ratings',
#  '462 ratings',
#  '208 ratings',
#  '962 ratings',
#  '6,853 ratings',
#  '30 ratings',
#  '2,762 ratings',
#  '512 ratings',
#  '426 ratings',
# ...

# %%
len(No_Rating_1)
# Out:
# 69

# %%
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #fetching rating
    try:
        rating=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']")
        Ratings.append(rating.text)
        
    except NoSuchElementException:
        Ratings.append('-')

# %%
Ratings
# Out:
# ['4.2 out of 5',
#  '3.7 out of 5',
#  '3.9 out of 5',
#  '3.7 out of 5',
#  '2.7 out of 5',
#  '3 out of 5',
#  '3.5 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '4.3 out of 5',
#  '4.3 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '2.9 out of 5',
#  '2.9 out of 5',
#  '4 out of 5',
#  '3.2 out of 5',
#  '4.1 out of 5',
#  '4 out of 5',
#  '2.8 out of 5',
#  '4 out of 5',
#  '3.7 out of 5',
#  '3.9 out of 5',
#  '4.1 out of 5',
#  '4 out of 5',
#  '3.6 out of 5',
#  '4 out of 5',
#  '3.2 out of 5',
#  '3.6 out of 5',
#  '4.1 out of 5',
#  '4 out of 5',
#  '3.9 out of 5',
#  '4.3 out of 5',
#  '3.9 out of 5',
#  '4.2 out of 5',
#  '4.1 out of 5',
#  '5 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.4 out of 5',
#  '4.1 out of 5',
#  '3.9 out of 5',
#  '3.8 out of 5',
#  '2.5 out of 5',
#  '3.3 out of 5',
#  '4.1 out of 5',
#  '2.8 out of 5',
#  '4.1 out of 5',
#  '3.6 out of 5',
#  '3.1 out of 5',
# ...

# %%
len(Ratings)
# Out:
# 69

# %%
Ret_exc=[]

# %%
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #fetching ret/exc
    try:
        re=driver.find_element_by_xpath("//a[@class='a-size-small a-link-normal a-text-normal']")
        Ret_exc.append(re.text)
        
    except NoSuchElementException:
        Ret_exc.append('-')

# %%
Ret_exc
# Out:
# ['30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '-',
#  '-',
#  '-',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '30 Days Returns & Exchange',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '90 Day Warranty',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '30 Days Returns',
#  '-',
#  '-',
#  '-',
# ...

# %%
len(Ret_exc)
# Out:
# 69

# %%
other_det=[]

# %%
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #fetching for other details
    try:
        Det=driver.find_element_by_id('feature-bullets')
        other_det.append(Det.text)
        
    except NoSuchElementException:
        other_det.append('-')

# %%
other_det
# Out:
# ['Sole: Ethylene Vinyl Acetate\nClosure: Pull On\nShoe Width: Regular\nOuter Material: Mesh\nClosure Type: Slip On\nToe Style: Round Toe\nWarranty Type: Manufacturer\nWarranty Description: 90 days',
#  'Sole: Ethylene Vinyl Acetate\nClosure: Lace-Up\nShoe Width: Medium\nUpper Material: Mesh\nSole Material: Eva\nClosure: Lace-ups\nLifestyle-Sports\nCare Instructions: Wipe with a clean, dry cloth when needed Do not wash with detergent or in washing machine',
#  'Closure: Lace-Up\nShoe Width: Medium\nFor: Men\nVery Soft and comfortable\nDurable Product',
# ...

# %%
len(other_det)
# Out:
# 69

# %% [markdown]
# As length of all the list is same, we will make dataframe.

# %%
roduct_Name_1=[]
Price_1=[]
No_Rating_1=[]
Ratings=[]

# %%
Shoes=pd.DataFrame({})

# %%
driver.close()

# %% [markdown]
# 3. Write a python program to access the search bar and search button on images.google.com and
# scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://images.google.com/')

# %%
#for search bar
search=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="546e80241ee2b6780620806d6dcedfaa", element="3121ec8b-b7cd-4cf1-a9e6-9b6ff4cf30c8")>

# %%
search.send_keys('fruits')

# %%
btn=driver.find_element_by_xpath("//div[@class='FAuhyb']")

# %%
btn.click()

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.google.com/search?q=fruits&tbm=isch&source=hp&biw=1036&bih=674&ei=JoSzYOSrMpvH4-EPqPmF4Ao&oq=fruits&gs_lcp=CgNpbWcQDDIFCAAQsQMyBQgAELEDMggIABCxAxCDATIFCAAQsQMyBQgAELEDMgUIABCxAzIFCAAQsQMyBQgAELEDMggIABCxAxCDATIFCAAQsQNQgvgHWJf4B2DG4gxoAHAAeAKAAf0BiAGgB5IBBTAuMS4zmAEAoAEBqgELZ3dzLXdpei1pbWc&sclient=img&ved=0ahUKEwjk1uWZs_HwAhWb4zgGHah8AawQ4dUDCAc'

# %%
r=requests.get(url)

# %%
soup=BeautifulSoup(r.text,'html.parser')

# %%
images=soup.find_all('img')

# %%
for image in images:
    print(image['src'])
# Out:
# /images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTZHIFXuE7BzskemzHmNPU3cXoigwce2xcv8KYcWwK2yL5AHabTPMdQAfz9Lw&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR0LKmpIvlfnBSF6dCtQF7rKEVJgWMMwHT8qBIgARErOMEwtt4UUjsUnXxUiTw&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTe0v2g_QGYXqYRupDq4lrjYs6KYWi3krBEAtOk9jkoQaP0UT0gRMdQKQ_F6AM&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ5AchXLTJ5JYEvXEW-SqkdvXPwrs0mkBibmTU1wNeb6dkqOd9piCUgxuMXag&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRvLCDra1-f4yYFZ_Da1mlxTXPsOJ8Idz0c1OhWv7whTcKMmEj6jGY9z8QLI6k&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRgmWfcGZ8MaatSc-7OPMlLqvCnuJXTpcBanoxOyBY3tHU2GFn5zIe3Pr1RDws&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQE7T9x93HcU858UrGHBoW9MmDvqGo-geMbRjqC5GfHKF-uR5pC0kteyA835A&s
# ...

# %%
#for cars
search=driver.find_element_by_xpath("//input[@class='og3lId']")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="546e80241ee2b6780620806d6dcedfaa", element="2385eaa1-5f65-4769-b22a-e91ff7f74858")>

# %%
search.send_keys('cars')

# %%
btn=driver.find_element_by_xpath("//div[@class='XZ5MVe']")
btn.click()

# %%
url='https://www.google.com/search?q=cars&tbm=isch&ved=2ahUKEwi6u4v-s_HwAhUChEsFHb2bAFUQ2-cCegQIABAA&oq=cars&gs_lcp=CgNpbWcQDDIECAAQQzIECAAQQzIFCAAQsQMyBQgAELEDMgIIADIFCAAQsQMyBQgAELEDMgIIADIFCAAQsQMyBQgAELEDOgcIABCxAxBDOggIABCxAxCDAVDFvQJYlP4OYOX1E2gAcAB4BoAB8wGIAf8LkgEFMC41LjSYAQCgAQGqAQtnd3Mtd2l6LWltZ7ABAMABAQ&sclient=img&ei=-YSzYPraCYKIrtoPvbeCqAU&bih=674&biw=1036'

# %%
r=requests.get(url)

# %%
soup=BeautifulSoup(r.text,'html.parser')

# %%
images=soup.find_all('img')

# %%
for image in images:
    print(image['src'])
# Out:
# /images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS59vgeXdSCETHjjX3Ed7gM5SpOPVW7HbNWFWOHAA3Z82tYMrFmf2Kerw48tzU&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSNiBlr5Dmp5FjQsgZizTB1gnPleXgfExedW9_cK5U7NxnjifETgolZhS-fnA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRoyJJMIRwWrPIgihZ_nyjXStkZ2oXqOYUpu6nlNyDiluXOJHXfUFFK_oAeVeY&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2F4t0MfMMkSoUEj94CUPgJuZTcX_QRxvqtXr_vE4RcjkD2I-6s88e9O1qiws&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ1ZaAKrQyLv6xGh7fWhL6J5eaapZ-lf1l0mBBA1mMaGwqieE9PH_ujaqc80g&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQi3zkEllvjo7sr_YmhlF7wxsw9KGnIPkQCF_uOUJ9CijgP08cuqKRw-e5IPvo&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTn2eof-30-PRLsfF2tPyjVd9i5eZl6QJaK8cfkIcglVxV0agr8rPT6LGHasoI&s
# ...

# %%
#for Machine Learning

search=driver.find_element_by_xpath("//input[@class='og3lId']")

# %%
search.send_keys('machine learning')

# %%
btn=driver.find_element_by_xpath("//div[@class='XZ5MVe']")
btn.click()

# %%
url='https://www.google.com/search?q=machine+learning&tbm=isch&ved=2ahUKEwjv_a6-u_HwAhV_mUsFHSlJDEIQ2-cCegQIABAA&oq=machine+learning&gs_lcp=CgNpbWcQDDIFCAAQsQMyAggAMgIIADICCAAyAggAMgIIADICCAAyBQgAELEDMgIIADICCAA6BAgAEENQsZELWI7RDWDfkRFoAHAAeAOAAcICiAHBC5IBBzAuMy4yLjKYAQCgAQGqAQtnd3Mtd2l6LWltZ7ABAMABAQ&sclient=img&ei=14yzYK82_7Ku2g-pkrGQBA&bih=674&biw=1036'

# %%
r=requests.get(url)
soup=BeautifulSoup(r.text,'html.parser')
images=soup.find_all('img')

# %%
for image in images:
    print(image['src'])
# Out:
# /images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT7TdIBku0JWpZvn3e98YIOy9Tf0SLRtlj0sXo2efNHJc0EVvG8UVl-DTzGB8U&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTkSeVOBlwJh9oTnDqYcU5Hz28fKfc9zCuVYHE0_5jPNHuCGqojLm7wxwhxTg&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTpHIlXhhSH-ZfUz1KxLMPQWI5xTNoVgfGxBjYWSx33Wk8rK9guD0A_3QFiRw&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRlx8mbpqfaG_a2UL_m7kzWSnRf9sJGw7WZzFYOtLi5KS5gEcf1Sx9sVZNpmA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSUTmKgE7GJiCzq0dCu2-FzR2rJg_7PNj9CzRobRVmd7vlMFiFnfrDvxCuR498&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTEsPDN3p8C0rkTC1_wn30jhKAN1Hm5ry0C08-SxtEzxRKTM-zeffzdfLiy63s&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRN2qCg0oGi9ohd6U5SHO0wz-u_w-BR4TsrC_7gUYJGJMBHZ-KwDiuQx3PS7w&s
# ...

# %%
driver.close()

# %%
from selenium.common.exceptions import ElementNotInteractableException

# %% [markdown]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page.
# Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”,
# “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display
# Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”.
# Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe
# and CSV.

# %%
url='https://www.flipkart.com/'

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
search=driver.find_element_by_xpath("//input[@class='_3704LK']")
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="fb9900c8-ff42-432c-b6ca-5e14be5b6b5f")>

# %%
search.send_keys("Pixel 4A")

# %%
btn=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
btn.click()

# %%
brand=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
brand
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="a03024c2-660f-49d5-b93f-8c5df485b855")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="fdbeaf9a-3f2f-4339-a44c-1582c254a616")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="10f6317f-29b8-4ff8-841d-2ba6b130837d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="ebe8c15d-c256-4126-a205-5e70916b07d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="597612af-d6b8-4b17-b43e-600df2d7fc1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="3b4ba25f-3674-41cd-86d4-3898439ba405")>,
# ...

# %%
Brands_name=[]
for i in brand:
    Brands_name.append(i.text)
Brands_name
# Out:
# ['Google Pixel 4a (Just Black, 128 GB)',
#  'REDMI 9 Power (Electric Green, 64 GB)',
#  'REDMI 9 Power (Mighty Black, 64 GB)',
#  'REDMI 9 Power (Blazing Blue, 64 GB)',
#  'REDMI Note 9 (Shadow Black, 64 GB)',
#  'REDMI Note 9 (Arctic White, 64 GB)',
#  'REDMI Note 9 (Pebble Grey, 64 GB)',
#  'REDMI 9 Power (Fiery Red, 64 GB)',
#  'REDMI Note 9 (Aqua Green, 64 GB)',
#  'REDMI 9 Power (Mighty Black, 128 GB)',
#  'Redmi 9 (Sky Blue, 64 GB)',
#  'Redmi 9 (Carbon Black, 64 GB)',
#  'SAMSUNG Galaxy M31 (Space Black, 128 GB)',
#  'REDMI Note 9 (Pebble Grey, 128 GB)',
#  'REDMI Note 9 (Arctic White, 128 GB)',
#  'REDMI 9 Prime (Matte Black, 64 GB)',
#  'REDMI 9 Power (Mighty Black, 128 GB)',
#  'Redmi 9A (Midnight Black, 32 GB)',
#  'Redmi 9A (Nature Green, 32 GB)',
#  'Redmi 9A (SeaBlue, 32 GB)',
#  'SAMSUNG Galaxy M31 (Ocean Blue, 128 GB)',
#  'ViVO Y20G (Purist Blue, 128 GB)',
#  'SAMSUNG Galaxy M02 (Blue, 32 GB)',
#  'Redmi 9 (Sky Blue, 128 GB)']

# %%
price=driver.find_elements_by_xpath("//div[@class='_30jeq3 _1_WHN1']")
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="697c2995-0569-41ae-afbe-994d19cd6650")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="0fbebdba-43de-41fc-a5d6-f131a23c4bef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="6bb5554f-d190-4207-bdcc-0b687ac792dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="3292d603-beb2-48e4-b48c-b72689b0121a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="ce3305e4-06b5-451e-8979-a107026c221b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="25961e46-c10b-4320-bb16-bd5a2f36aba3")>,
# ...

# %%
Price=[]
for i in price:
    Price.append(i.text)
Price
# Out:
# ['₹31,999',
#  '₹9,999',
#  '₹9,999',
#  '₹9,999',
#  '₹10,999',
#  '₹10,999',
#  '₹10,999',
#  '₹9,999',
#  '₹10,999',
#  '₹12,999',
#  '₹9,015',
#  '₹8,860',
#  '₹16,900',
#  '₹12,999',
#  '₹12,999',
#  '₹9,999',
#  '₹11,999',
#  '₹7,184',
#  '₹7,380',
#  '₹7,138',
#  '₹18,521',
#  '₹14,990',
#  '₹8,098',
#  '₹10,083']

# %%
len(Brands_name)
# Out:
# 24

# %%
len(Price)
# Out:
# 24

# %%
#fetching urls
urls=[]
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    urls.append(i.get_attribute("href"))
    
urls
# Out:
# ['https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=Pixel+4A&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=SEARCH&iid=b2a996d4-dfa7-4624-9d3c-d7f9251e3a56.MOBFUSBNAZGY7HQU.SEARCH&ppt=hp&ppn=homepage&ssid=210t64nc1c0000001622439787452&qH=aeec4064cb2b1348',
#  'https://www.flipkart.com/redmi-9-power-electric-green-64-gb/p/itmca7d78e222ed7?pid=MOBFYZ7AVAXXB2TH&lid=LSTMOBFYZ7AVAXXB2THVSNL0U&marketplace=FLIPKART&q=Pixel+4A&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=SEARCH&iid=b2a996d4-dfa7-4624-9d3c-d7f9251e3a56.MOBFYZ7AVAXXB2TH.SEARCH&ppt=hp&ppn=homepage&ssid=210t64nc1c0000001622439787452&qH=aeec4064cb2b1348',
# ...

# %%
len(urls)
# Out:
# 24

# %%
desc=driver.find_elements_by_xpath("//div[@class='fMghEO']")
desc
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="1d17cc69-7f8d-42cd-bdf4-403cdbcce9d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="72263091-e4a9-4ef8-b833-0c501e5f3117")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="2427ee4d-9950-47a4-bb71-b09d8c03439e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="de43d889-d095-4ce3-9ac4-4613abafb0dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="4149e6ed-2482-408a-af27-d632a0cdae10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c996e45630d6da5cfadfed8c2e16b17", element="390bf4cb-a5d1-49d2-a8e4-45e99f54b3d9")>,
# ...

# %%
prod_desc=[]
for i in desc:
    prod_desc.append(i.text)
prod_desc
# Out:
# ['6 GB RAM | 128 GB ROM\n14.76 cm (5.81 inch) Full HD+ Display\n12.2MP Rear Camera | 8MP Front Camera\n3140 mAh Battery\nQualcomm Snapdragon 730G Processor\nOLED Display\n1 Year Warranty',
#  '4 GB RAM | 64 GB ROM\n16.59 cm (6.53 inch) Full HD+ Display\n48MP Rear Camera | 8MP Front Camera\n6000 mAh Battery\nQualcomm Snapdragon 662 Processor\n1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase',
#  '4 GB RAM | 64 GB ROM\n16.59 cm (6.53 inch) Full HD+ Display\n48MP Rear Camera | 8MP Front Camera\n6000 mAh Battery\nQualcomm Snapdragon 662 Processor\n1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase',
# ...

# %%
len(prod_desc)
# Out:
# 24

# %%
Mob_Det=pd.DataFrame({})
Mob_Det['Brands']=Brands_name
Mob_Det['Price']=Price
Mob_Det['Urls']=url
Mob_Det['prod_desc']=prod_desc

# %%
Mob_Det.to_csv('Mob_Details.csv')

# %%
df=pd.read_csv('Mob_Details.csv')

# %%
df
# Out:
#     Unnamed: 0                                    Brands    Price  \
# 0            0      Google Pixel 4a (Just Black, 128 GB)  ₹31,999
# 1            1     REDMI 9 Power (Electric Green, 64 GB)   ₹9,999
# 2            2       REDMI 9 Power (Mighty Black, 64 GB)   ₹9,999
# 3            3       REDMI 9 Power (Blazing Blue, 64 GB)   ₹9,999
# 4            4        REDMI Note 9 (Shadow Black, 64 GB)  ₹10,999
# 5            5        REDMI Note 9 (Arctic White, 64 GB)  ₹10,999
# 6            6         REDMI Note 9 (Pebble Grey, 64 GB)  ₹10,999
# 7            7          REDMI 9 Power (Fiery Red, 64 GB)   ₹9,999
# 8            8          REDMI Note 9 (Aqua Green, 64 GB)  ₹10,999
# 9            9      REDMI 9 Power (Mighty Black, 128 GB)  ₹12,999
# 10          10                 Redmi 9 (Sky Blue, 64 GB)   ₹9,015
# 11          11             Redmi 9 (Carbon Black, 64 GB)   ₹8,860
# 12          12  SAMSUNG Galaxy M31 (Space Black, 128 GB)  ₹16,900
# ...

# %%
driver.close()

# %% [markdown]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on
# google maps.

# %%
url='https://www.google.co.in/maps/@21.161057,79.07251,12z'

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get(url)

# %%
coordinates=driver.find_elements_by_xpath("//body[@class='keynav-mode-off highres screen-mode']")
coordinates
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="70b9444454518330f91492735d6fcfe8", element="acb8d1dd-53d0-41d5-b66c-186aa2085b0d")>]

# %% [markdown]
# 6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –
# September 20) from trak.in

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url="https://trak.in/"

# %%
driver.get(url)

# %%
deals=driver.find_element_by_id("menu-item-51510")
deals
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="336ef0a2-b91f-4a81-b040-3baeaec55988")>

# %%
deals.click()

# %%
#for the month of July

# %%
dates=driver.find_elements_by_xpath("//td[@class='column-2']")
dates
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="b55aecdc-08a5-4d2b-a974-03106f6d28cb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="a25698ca-d72d-4558-b894-d6cafe5862ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="a6b9c1cf-38c7-49dd-b2ea-e7269dcf638c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="595274f0-36c1-4aaa-8f32-f068037e9084")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="0bd0fa4c-9ca8-4da7-b24d-5e2024348a82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="3e45bd32-ed32-4d95-8db8-55a56c3679e3")>,
# ...

# %%
Date_JAS=[]
for i in dates:
    Date_JAS.append(i.text)
Date_JAS
# Out:
# ['01/04/2021',
#  '05/04/2021',
#  '14/04/2021',
#  '07/04/2021',
#  '14/04/2021',
#  '04/03/2021',
#  '31/03/2021',
#  '30/03/2021',
#  '30/03/2021',
#  '23/03/2021',
#  '25/03/2021',
#  '26/03/2021',
#  '11/02/2021',
#  '22/02/2021',
#  '19/02/2021',
#  '17/02/2021',
#  '15/02/2021',
#  '12/02/2021',
#  '12/02/2021',
#  '09/02/2021',
#  '09/02/2021',
#  '15/01/2021',
#  '28/01/2021',
#  '19/01/2021',
#  '19/01/2021',
#  '18/01/2021',
#  '18/01/2021',
#  '11/01/2021',
#  '13/01/2021',
#  '15/12/2020',
#  '21/12/2020',
#  '15/12/2020',
#  '22/12/2020',
#  '15/12/2020',
#  '18/12/2020',
#  '30/11/2020',
#  '30/11/2020',
#  '29/11/2020',
#  '27/11/2020',
#  '25/11/2020',
#  '25/11/2020',
#  '25/11/2020',
#  '24/11/2020',
#  '30/11/2020',
#  '23/11/2020',
#  '28/10/2020',
#  '28/10/2020',
#  '28/10/2020',
#  '27/10/2020',
#  '27/10/2020',
#  '27/10/2020',
#  '27/10/2020',
#  '15/10/2020',
#  '26/10/2020',
#  '28/10/2020',
#  '08/09/2020',
#  '12/09/2020',
#  '09/09/2020',
# ...

# %%
len(Date_JAS)
# Out:
# 392

# %%
Dates=Date_JAS[47:85]
Dates
# Out:
# ['28/10/2020',
#  '27/10/2020',
#  '27/10/2020',
#  '27/10/2020',
#  '27/10/2020',
#  '15/10/2020',
#  '26/10/2020',
#  '28/10/2020',
#  '08/09/2020',
#  '12/09/2020',
#  '09/09/2020',
#  '02/09/2020',
#  '09/09/2020',
#  '07/09/2020',
#  '07/09/2020',
#  '31/08/2020',
#  '31/08/2020',
#  '03/09/2020',
#  '15/08/2020',
#  '13/08/2020',
#  '13/08/2020',
#  '04/08/2020',
#  '11/08/2020',
#  '12/08/2020',
#  '14/08/2020',
#  '10/08/2020',
#  '07/08/2020',
#  '13/08/2020',
#  '15/07/2020',
#  '16/07/2020',
#  '16/07/2020',
#  '14/07/2020',
#  '13/07/2020',
#  '09/07/2020',
#  '10/07/2020',
#  '15/07/2020',
#  '14/07/2020',
#  '13/07/2020']

# %%
Startup=driver.find_elements_by_xpath("//td[@class='column-3']")
Startup
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="f47cddf4-fcee-4161-be8e-ab1570109724")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="37249125-c673-4b37-862f-f05a8934e198")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="9f184515-cf0e-4778-99b9-3b0765d20161")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="43de8f23-91d5-4992-a6b8-45736b0f758f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="37be2250-39db-4eb6-8cd0-6fae58a1c7c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="4bf2aca4-46ae-4455-88f0-41fcced9e23a")>,
# ...

# %%
Sname=[]
for i in Startup:
    Sname.append(i.text)
Sname
# Out:
# ['BYJU’S',
#  'Meesho',
#  'Swiggy',
#  'Groww',
#  'Beldara',
#  'DealShare',
#  'Uniphore',
#  'Dunzo',
#  'BYJU’S',
#  'SkilloVilla',
#  'CityMall',
#  'DotPe',
#  'Doubtnut',
#  'Zomato',
#  'Fingerlix',
#  'Zolve',
#  'KreditBee',
#  'Pepperfry',
#  'Grofers',
#  'Nothing',
#  'SplashLearn',
#  'Digit Insurance',
#  'Bombay Shaving Company',
#  'DeHaat',
#  'Darwinbox',
#  'mfine',
#  'Udayy',
#  'True Elements',
#  'Saveo',
#  'Bira 91',
#  'Pine Labs',
#  'Zenoti',
#  'Tax Buddy India',
#  'Delhivery',
#  'PagarBook',
#  'Codingal',
#  'CRED',
#  'Bira 91',
#  'Chumbak',
#  'Cityflo',
#  'Shipsy',
#  'Unacademy',
#  'Cashfree',
#  'Credgenics',
#  'Country Delight',
#  'Nykaa',
#  'Betterplace',
#  'FlexiLoans',
#  'GetVantage',
#  'FreshToHome',
#  'Origo',
#  'Origo',
#  'Treebo Hotels',
#  'Hubilo',
#  'CredAble',
#  'Byju’s',
#  'mCaffeine',
#  'Qshala',
#  'Winzo',
#  'Hippo Video',
#  'Melorra',
#  '1mg',
#  'mfine',
#  'Apna',
#  'Railofy',
#  'Practo',
#  'Medlife',
# ...

# %%
len(Sname)
# Out:
# 392

# %%
Startup_branadname=Sname[47:85]
Startup_branadname
# Out:
# ['FlexiLoans',
#  'GetVantage',
#  'FreshToHome',
#  'Origo',
#  'Origo',
#  'Treebo Hotels',
#  'Hubilo',
#  'CredAble',
#  'Byju’s',
#  'mCaffeine',
#  'Qshala',
#  'Winzo',
#  'Hippo Video',
#  'Melorra',
#  '1mg',
#  'mfine',
#  'Apna',
#  'Railofy',
#  'Practo',
#  'Medlife',
#  'HungerBox',
#  'Dunzo',
#  'Terra.do',
#  'Classplus',
#  'Niyo',
#  'ZestMoney',
#  'FreshToHome',
#  'Eduvanz',
#  'Flipkart',
#  'Vedantu',
#  'Crio',
#  'goDutch',
#  'Mystifly',
#  'JetSynthesys',
#  'gigIndia',
#  'PumPumPum',
#  'FLYX',
#  'Open Appliances Pvt. Ltd.']

# %%
industry=driver.find_elements_by_xpath("//td[@class='column-4']")
industry
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="85215bcc-b228-4e79-97a2-407e08e78a3a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="1368fd25-fd7b-4b6e-8d53-1549f9fd8c88")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="be14eea9-90bc-4f06-a23a-b36b5ce3240b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="63acc1d0-531b-4b73-bfc2-4de5d2402cbd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="b78541a8-be2f-4924-91a2-6acf3de4c360")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="2dd0e318-ea6e-4202-8328-392ddb7daf49")>,
# ...

# %%
ind=[]
for i in industry:
    ind.append(i.text)
ind
# Out:
# ['Edu-tech',
#  'E-commerce',
#  'Online Food Delivery',
#  'FinTech',
#  'E-commerce',
#  'E-commerce',
#  'Technology',
#  'E-commerce',
#  'Edu-tech',
#  'Edu-tech',
#  'E-commerce',
#  'FinTech',
#  'Edu Tech',
#  'Hospitality',
#  'Hospitality',
#  'FinTech',
#  'Finance',
#  'E-commerce',
#  'E-Commerce',
#  'Technology',
#  'EdTech',
#  'Financial Services',
#  'Consumer Goods Company',
#  'AgriTech Startup',
#  'SaaS',
#  'Health Tech Startup',
#  'EdTech',
#  'Food Startup',
#  'B2B E-commerce',
#  'Food and Beverage',
#  'Financial Services',
#  'Technology Provider',
#  'FinTech',
#  'Supply chain',
#  'SaaS',
#  'EduTech',
#  'Financial Services',
#  'Food and Beverage',
#  'Lifestyle',
#  'Transportation',
#  'SaaS',
#  'Edutech',
#  'FinTech',
#  'Fintech',
#  'Dairy Tech',
#  'E-commerce',
#  'Digital Solutions',
#  'FinTech',
#  'FinTech',
#  'E-commerce',
#  'AgriTech',
#  'Advertising',
#  'Hospitality',
#  'Information Technology',
#  'FinTech',
#  'EduTech',
# ...

# %%
len(ind)
# Out:
# 392

# %%
Industry_Vertical=ind[47:85]
Industry_Vertical
# Out:
# ['FinTech',
#  'FinTech',
#  'E-commerce',
#  'AgriTech',
#  'Advertising',
#  'Hospitality',
#  'Information Technology',
#  'FinTech',
#  'EduTech',
#  'Personal Care',
#  'EduTech',
#  'Online Gaming',
#  'Video Customer Experience(CX) Platform',
#  'E-commerce',
#  'E-commerce',
#  'HealthTech',
#  'Human Resources',
#  'Transportation',
#  'HealthTech',
#  'E-commerce',
#  'FoodTech',
#  'Hyper-local Logistics',
#  'EduTech',
#  'EduTech',
#  'FinTech',
#  'FinTech',
#  'E-commerce',
#  'FinTech',
#  'E-commerce',
#  'EduTech',
#  'EduTech',
#  'FinTech',
#  'Airfare Marketplace',
#  'Gaming and Entertainment',
#  'Marketplace',
#  'Automotive Rental',
#  'OTT Player',
#  'Information Technology']

# %%
sv=driver.find_elements_by_xpath("//td[@class='column-5']")
sv
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="6b2ddc78-41b7-4004-aaa8-c95981182e40")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="f52aa464-8126-402a-8a97-2205afe61e95")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="5afa842b-392d-4f53-b0a2-b5039f0c3bb2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="83d3baa5-1f20-4539-a0f4-143b5e1ea988")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="05bc1325-e02d-4067-b8ce-2dec6e3d803b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="1b4d5c52-62aa-4b5e-97fc-9e419715b115")>,
# ...

# %%
SV=[]
for i in sv:
    SV.append(i.text)
SV
# Out:
# ['Online tutoring',
#  'Online reselling platform',
#  'Online Food Delivery',
#  'Investment platform',
#  'Global B2B marketplace',
#  'Online shopping platform',
#  'Conversational Service Automation (CSA)',
#  'Hyper-local delivery app',
#  'Online tutoring',
#  'Career and job-oriented upskilling.',
#  'Social ecommerce and online grocery platform',
#  'Commerce and payments platform to offline enterprise businesses.',
#  'E-Learning Platform',
#  'Online Food Delivery Platform',
#  'Semi-cooked food delivery app',
#  'Global Neobank Venture',
#  'Digital lending platform',
#  'Multi-brand furniture brand',
#  'Online supermarket',
#  'Consumer Technology Venture',
#  'Game-based learning programme',
#  'Insurance Services',
#  'Shave care, beard care, and skincare products',
#  'online marketplace for farm products and services',
#  'HR Tech',
#  'AI-powered telemedicine mobile app',
#  'Online learning platform for kids in class 1-5',
#  'Whole Food plant based Nashta',
# ...

# %%
Sub_Vertical=SV[47:85]
Sub_Vertical
# Out:
# ['Digital Lending Platform',
#  'Revenue-Based Financing Platform',
#  'Food Delivery',
#  'Agricultural Commodities Management',
#  'Online Video Editing',
#  'Budget Hospitality Chain',
#  'Virtual Events Platform',
#  'Supply Chain Finance',
#  'Online Tutoring',
#  'Skincare & Haircare',
#  'Online Curiosity Platform for Kids',
#  'Online Gaming',
#  'Video Customer Experience(CX) Platform',
#  'Online Jewelry Store',
#  'Online Pharmacy',
#  'On-Demand Healthcare Services',
#  'Recruitment Platform',
#  'WL & RAC protection platform',
#  'Health care and Wellness',
#  'Online Pharmacy',
#  'Online Food Delivery Service',
#  'Online Delivery Services',
#  'Online Climate School, E-learning',
#  'E-learning, Online Tutoring',
#  'Financial Services',
#  'Financial Services',
#  'Food Delivery',
#  'Financial Services',
#  'E-commerce',
#  'Online Tutoring',
#  'Learning Platform for Developers',
#  'Group Payments',
#  'Ticketing, Airline Retailing, and Post-Ticketing Services',
# ...

# %%
cilo=driver.find_elements_by_xpath("//td[@class='column-6']")
cilo
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="71745b20-031f-4aae-9782-649911bc9a00")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="2fdb4fa9-b63e-4a2f-980d-050161a5ee9f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="1a7f2f31-7f06-4a98-9b7b-e35590be8bda")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="5976173f-f3a4-4701-a757-328649f7e2f2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="56747d73-73d7-4292-b4ef-4aa357ef8033")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="7157d5e5-2a3f-44c9-873c-3f0467956943")>,
# ...

# %%
city=[]
for i in cilo:
    city.append(i.text)
city
# Out:
# ['Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Mumbai',
#  'Jaipur, Rajasthan',
#  'Palo Alto',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Gurgaon',
#  'Gurgaon',
#  'Gurgaon',
#  'Gurgaon',
#  'Mumbai',
#  'Mumbai',
#  'Bengaluru',
#  'Mumbai',
#  'Gurgaon',
#  'London',
#  'Gurgaon',
#  'Bengaluru',
#  'New Delhi',
#  'Patna',
#  'Mumbai',
#  'Bengaluru',
#  'Gurgaon',
#  'Pune',
#  'Bengaluru',
#  'New Delhi',
#  'Noida',
#  'Washington',
#  'Mumbai',
#  'Gurgaon',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'New Delhi',
#  'Bengaluru',
#  'Mumbai',
#  'Gurgaon',
#  'Bengaluru',
#  'Bengaluru',
#  'Gurgaon',
#  'Gurugram',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Mumbai',
#  'Bangalore',
#  'Gurgaon',
#  'Mumbai',
#  'Bangalore',
#  'Wilmington, Delaware, United States',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'New Delhi',
#  'Newark, Delaware, United States of Amercia',
#  'Bangalore',
#  'Gurgaon',
#  'Bangalore',
# ...

# %%
City=city[47:85]
City
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Bangalore',
#  'Gurgaon',
#  'Mumbai',
#  'Bangalore',
#  'Wilmington, Delaware, United States',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'New Delhi',
#  'Newark, Delaware, United States of Amercia',
#  'Bangalore',
#  'Gurgaon',
#  'Bangalore',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Stanford, California,',
#  'Noida',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Mumbai',
#  'Singapore and Bangalore',
#  'Pune',
#  'Pune',
#  'Gurgaon',
#  'New York and Delhi',
#  'Bangalore']

# %%
inv=driver.find_elements_by_xpath("//td[@class='column-7']")
inv
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="418e2729-e1d1-4e89-9c49-b9541d2cebbb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="e2ee6824-ddb0-479c-af8e-51109820a8de")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="d6040ddd-58e0-4ae1-9ba3-ecda9a0a23aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="5759da53-ffbb-483f-8fea-2fe122f1e5f2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="6adf1f01-3ebb-4db7-af79-15b314838e08")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="84540137-2350-4f68-ae17-c04da1b84ae6")>,
# ...

# %%
Inv=[]
for i in inv:
    Inv.append(i.text)
Inv
# Out:
# ['Innoven Capital',
#  'SoftBank Vision Fund 2',
#  'Amansa Holdings, Carmignac, Falcon Edge Capital, Goldman Sachs, Think Investments',
#  'MC Global Edtech, B Capital, Baron, others',
#  'Hindustan Media Ventures',
#  'Innoven Capital',
#  'Sorenson Capital Partners',
#  'Krishtal Advisors Pte Ltd',
#  'MC Global Edtech, B Capital, Baron, others',
#  'Titan Capital, others',
#  'Accel Partners',
#  'PayU',
#  'SIG Global, Sequoia Capital, WaterBridge Ventures and ON Mauritius',
#  'Tiger Global, Kora',
#  'Rhodium Trust, Accel Partners and Swiggy',
#  'Accel Partners and Lightspeed Venture Partners',
#  'Azim Premji’s PremjiInvest and South Korea’s Mirae Asset Venture',
#  'InnoVen Capital',
#  'SoftBank Vision Fund (SVF)',
#  'GV',
#  'Owl Ventures',
#  'A91 Partners, Faering Capital, TVS Capital Funds',
#  'Reckitt Benckiser',
#  'Prosus Ventures',
#  'Salesforce Ventures',
#  'Heritas Capital Management',
#  'Sequoia Capital',
#  'SIDBI Venture Capital',
# ...

# %%
Investors=Inv[47:85]
Investors
# Out:
# ['Falguni and Sanjay Nayar Family Office',
#  'Chiratae Ventures, Dream Incubators',
#  'Corporation of Dubai (ICD), Ascent Capital, DFC, the Allana Group',
#  'Northern Arc Capital',
#  'Sequoia Capital India',
#  'Matrix Partners India, SAIF Partners, Ward Ferry Management and Bertelsmann India',
#  'Lightspeed Venture Partners',
#  'Oaks Asset Management and V’Ocean Investment',
#  'Silver Lake, Tiger Global, General Atlantic and Owl Ventures',
#  'Amicus Capital Private Equity I LLP, Amicus Capital Partners India Fund I and RP-SG Venture Fund 1',
#  'Rainmatter Capital',
#  'Kalaari Capital Partners, IndigoEdge Management Consultancy',
#  'Alpha Wave Incubation, Exfinity Venture Partners and existing backers.',
#  'Shadow Holdings, Lightbox.',
#  'Gaja Capital, Tata Capital, Partners Group',
#  'Caretech Pte Inc',
#  'Lightspeed India and Sequoia Capital India',
#  'Chiratae Ventures',
#  'A1A Company',
#  'Prasid Uno Family Trust and SC Credit Fund',
# ...

# %%
inv_t=driver.find_elements_by_xpath("//td[@class='column-8']")
inv_t
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="86a47bd0-0de4-4dd5-89e6-53483c8f98fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="d9ed0910-2d13-489e-ae5a-5527e6b46c5c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="3d219013-7df6-42ca-b3cf-a98b5ba33046")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="d9fe3674-0f57-4774-8a5b-fb988ecf2b63")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="80cba177-94c4-42a9-a3db-d0f5ad9ee894")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="2e398e29-1fdf-4559-ab71-feb50df3d436")>,
# ...

# %%
Inv_t=[]
for i in inv_t:
    Inv_t.append(i.text)
Inv_t
# Out:
# ['Series F',
#  'Series E',
#  'Series J',
#  'Series D',
#  'Venture',
#  'Debt Financing',
#  'Series D',
#  'Series E',
#  'Series F',
#  'Seed',
#  'Series A',
#  'Series A',
#  'Series B',
#  'Venture',
#  'Series C',
#  'Seed',
#  'Series C',
#  'Debt Financing',
#  'Unspecified',
#  'Series A',
#  'Series C',
#  'Venture',
#  'Venture',
#  'Series C',
#  'Seed',
#  'Venture Round',
#  'Seed Funding',
#  'Series',
#  'Seed',
#  'Funding',
#  'Secondary Market',
#  'Series D',
#  'Seed',
#  'Secondary Market',
#  'Series A',
#  'Seed',
#  'Series C',
#  'Bridge Funding',
#  'Pre-series E',
#  'Series A',
#  'Series A',
#  'Venture',
#  'Series B',
#  'Pre-Series A',
#  'Series C',
#  'Personal Investment',
#  'Series B',
#  'Equity and Debt',
#  'Seed',
#  'Series C',
#  'Debt',
#  'Series A',
#  '',
#  'Seed',
#  'Follow-On',
#  'Private Equity',
#  'Series B',
#  'Angel',
#  'Series B',
#  'Series A',
#  'Debt Financing',
#  'In Progress',
#  'Series B',
#  'Series A',
# ...

# %%
Investor_type=Inv_t[47:85]
Investor_type
# Out:
# ['Equity and Debt',
#  'Seed',
#  'Series C',
#  'Debt',
#  'Series A',
#  '',
#  'Seed',
#  'Follow-On',
#  'Private Equity',
#  'Series B',
#  'Angel',
#  'Series B',
#  'Series A',
#  'Debt Financing',
#  'In Progress',
#  'Series B',
#  'Series A',
#  'Seed',
#  'Series F',
#  '',
#  'Series D1',
#  'In Progress',
#  'Seed',
#  'In Progress',
#  '',
#  '',
#  'Venture',
#  'Series A',
#  'M&A',
#  'Series D',
#  'pre-Series A',
#  'Seed',
#  'pre-Series B',
#  'Venture-Series Unknown',
#  'pre-Series A',
#  'Seed',
#  'pre-Seed',
#  'Venture-Series Unknown']

# %%
amt=driver.find_elements_by_xpath("//td[@class='column-9']")
amt
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="59ddd839-1066-4fcb-8a5a-80b6bab99f2f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="415077c7-36cb-49b0-9ef6-aa76566e5795")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="ae8900f9-acae-4bad-a7ef-532cee89dde1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="76fef2d3-54ea-45fa-91d5-4d43b2ad03ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="b8e7dc56-f752-48ca-8969-2b184388d059")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9ce5311c610b24122d9f537ff468c2ac", element="78f86022-4f3b-47c3-8364-1e7c629e80c7")>,
# ...

# %%
Amt=[]
for i in amt:
    Amt.append(i.text)
Amt
# Out:
# ['460,000,000',
#  '300,000,000',
#  '343,000,000',
#  '83,000,000',
#  '7,400,000',
#  '250,000,000',
#  '140,000,000',
#  '8,000,000',
#  '460,000,000',
#  '300,000,000',
#  '11,000,000',
#  '27,500,000',
#  '2,500,000',
#  '250,000,000',
#  '2,747,045.20',
#  '1,50,00,000',
#  '75,000,000',
#  '4,773,958',
#  '55,000,000',
#  '15,000,000',
#  '18,000,000',
#  '1,80,00,000',
#  '6,172,258.50',
#  '30,000,000',
#  '15,000,000',
#  '16,000,000',
#  '15,000,000',
#  '100,000,000',
#  '4,000,000',
#  '1,273,634.07',
#  'Undisclosed',
#  '160,000,000',
#  '1,000,000',
#  '25,000,000',
#  '15,000,000',
#  '560,000',
#  '80,000,000',
#  '3,000,000',
#  '1,001,047.92',
#  '7,700,000',
#  '6,003,806',
#  '75,000,000-100,000,000',
#  '35,300,000',
#  '3,500,000',
#  '25,000,000',
#  'NA',
#  '10,000,000',
#  '20,160,000',
#  '5,000,000',
#  '121,000,000',
#  '4,700,000',
#  '15,000,000',
#  '6,000,000',
#  '4,500,000',
#  '4,500,000',
#  '500,000,000',
#  '3,000,000',
#  '370,000',
# ...

# %%
Amount=Amt[47:85]
Amount
# Out:
# ['20,160,000',
#  '5,000,000',
#  '121,000,000',
#  '4,700,000',
#  '15,000,000',
#  '6,000,000',
#  '4,500,000',
#  '4,500,000',
#  '500,000,000',
#  '3,000,000',
#  '370,000',
#  '15,500,000',
#  '4,500,000',
#  'upto 8,900,000',
#  '100,000,000',
#  '5,400,000',
#  '8,000,000',
#  '950,000',
#  '32,000,000',
#  '23,000,000',
#  '1,560,000',
#  '30,000,000',
#  '1,400,000',
#  'upto 15,000,000',
#  '6,000,000',
#  '10,670,000',
#  '16,200,000',
#  '5,000,000',
#  '1,200,000,000',
#  '100,000,000',
#  '934,160',
#  '1,700,000',
#  '3,300,000',
#  '400,000',
#  '974,200',
#  '292,800',
#  '200,000',
#  '500,000']

# %%
driver.close()

# %% [markdown]
# 7. Write a program to scrap all the available details of top 10 gaming laptops from digit.in.

# %%
 url="https://www.digit.in/"

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
search=driver.find_element_by_xpath("//div[@class='search']")
search.click()

# %%
search_bar=driver.find_element_by_id('globalPageSearchText')
search_bar.send_keys('top 10 gaming laptops')

# %%
driver.get('https://www.digit.in/search?keyword=top+10+gaming+laptops')

# %%
name=driver.find_elements_by_xpath("//div[@class='searchProduct-desc']")
name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="03cdd93e9284a9defa64deaa8e88bfe9", element="5712b451-1596-4629-a688-b9b65d7d8351")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03cdd93e9284a9defa64deaa8e88bfe9", element="6b34df67-6ce3-4f9b-bee5-9818c3865694")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03cdd93e9284a9defa64deaa8e88bfe9", element="749510a3-a233-4c19-8da2-4dbb84cf85c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03cdd93e9284a9defa64deaa8e88bfe9", element="66e08e50-496e-490f-9b25-6c923830e071")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03cdd93e9284a9defa64deaa8e88bfe9", element="4505bab8-a976-4a97-8bb4-e9cd3c59a242")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="03cdd93e9284a9defa64deaa8e88bfe9", element="b9d3aa01-11cc-4086-8693-50906c0678b2")>,
# ...

# %%
Laptop_name=[]
for i in name:
    Laptop_name.append(i.text)
Laptop_name
# Out:
# ["ASUS G53J - A 3D gamer's delight but we want more",
#  'HP Envy 15-k006tx',
#  'Asus G750JX-CV069P',
#  'ASUS ROG Flow x13',
#  'Lenovo IdeaPad Y570',
#  'ASUS Zephyrus G15 Ryzen 9 5900HS (2021)',
#  'ASUS ROG Cetra',
#  'HP Pavilion g6 - Multimedia and gaming on a budget',
#  'Top gaming laptops under Rs 1 lakh',
#  'Top gaming laptops to target on Amazon India']
